# %% [markdown]
# # Optimization

# %% [markdown]
# ## Import Libraries

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import importlib
import numpy as np
import pandas as pd

from src import config
import src.optimization_utils as ou
import src.solutions as s
import src.display as disp
import src.runs as runs
from src.problem import SpineProblem

# Reload to pick up any changes
importlib.reload(ou)
importlib.reload(s)
importlib.reload(disp)
importlib.reload(runs)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load Models

# %%
# Load all models
model_configs = {
    "Mechanical Failure": config.MECH_FAIL_MODEL,
    "L4S1": config.L4S1_MODEL,
    "LL": config.LL_MODEL,
    "T4PA": config.T4PA_MODEL,
    "L1PA": config.L1PA_MODEL,
    "SVA": config.SVA_MODEL,
    "SS": config.SS_MODEL,
    "Global Tilt": config.GLOBAL_TILT_MODEL,
    "ODI": config.ODI_MODEL,
}

bundles = {name: ou.load_model_bundle(path) for name, path in model_configs.items()}

# Verify and display
print("Models loaded and verified:")
for name, bundle in bundles.items():
    status = "✓" if all(k in bundle for k in ["pipe", "features", "target"]) else "✗"
    print(f"  {status} {name}: {bundle.get('model_name', 'N/A')}")

# Extract individual bundles for use
mech_fail_bundle = bundles["Mechanical Failure"]
L4S1_bundle = bundles["L4S1"]
LL_bundle = bundles["LL"]
T4PA_bundle = bundles["T4PA"]
L1PA_bundle = bundles["L1PA"]
SVA_bundle = bundles["SVA"]
SS_bundle = bundles["SS"]
GT_bundle = bundles["Global Tilt"]
ODI_bundle = bundles["ODI"]

# Delta model bundles for postop predictions
delta_bundles = {
    "L4S1": L4S1_bundle,
    "LL": LL_bundle,
    "T4PA": T4PA_bundle,
    "L1PA": L1PA_bundle,
    "SS": SS_bundle,
    "GlobalTilt": GT_bundle,
    "SVA": SVA_bundle,
}
# Out:
# Models loaded and verified:
#   ✓ Mechanical Failure: mech_fail_logreg
#   ✓ L4S1: RidgeRegressor_delta_L4S1
#   ✓ LL: RandomForest_delta_LL
#   ✓ T4PA: RidgeRegressor_delta_T4PA
#   ✓ L1PA: RidgeRegressor_delta_L1PA
#   ✓ SVA: XGBRegressor_delta_SVA
#   ✓ SS: XGBRegressor_delta_SS
#   ✓ Global Tilt: XGBRegressor_delta_GlobalTilt
#   ✓ ODI: RidgeRegressor_delta_ODI

# %%
# ---- Check categories in training data vs each model ----
train_df = pd.read_csv(config.DATA_PROCESSED)
print("Training data:", config.DATA_PROCESSED)
print(f"  Shape: {train_df.shape}")
print(f"  ASA_CLASS unique: {sorted(train_df['ASA_CLASS'].dropna().unique())}")
print(f"  sex unique: {sorted(train_df['sex'].dropna().unique())}")
print(f"  UIV_implant unique: {sorted(train_df['UIV_implant'].dropna().unique())}")
print(f"  num_levels_cat unique: {sorted(train_df['num_levels_cat'].dropna().unique())}")
# Out:
# Training data: /Users/vanjaglisic/Documents/UW_MSDS/CAPSTONE/repo work/Data-Science-Capstone/data/processed/cleaned_for_modeling.csv
#   Shape: (271, 109)
#   ASA_CLASS unique: ['1', '2', '3', '4', '4E']
#   sex unique: ['FEMALE', 'MALE']
#   UIV_implant unique: ['FS', 'Hook', 'PS']
#   num_levels_cat unique: ['higher', 'lower']

# %% [markdown]
# ## Optimization Scenarios
#
# Each scenario uses a different set of composite score weights to explore how the optimizer behaves under different objectives. Predefined presets are in `src/runs.py`. To add a new scenario, add a new entry to `runs.PRESETS` and include its key below.

# %%
# =============================================================================
# SELECT SCENARIOS TO RUN
# =============================================================================
# Available presets (defined in src/runs.py):
#   "equal"           - All 6 alignment components weighted equally
#   "mech_fail"       - Primarily mech failure, small alignment weights
#   "mech_fail_t4l1pa"- Mech failure + T4PA-L1PA mismatch
#   "l4s1"            - Primarily L4-S1 in ideal range
#   "t4l1pa"          - Primarily T4PA-L1PA mismatch
#   "equal_plus_mech" - Composite (equal) blended 50/50 with mech failure
#   "odi"             - Primarily lowest predicted postop ODI
#   "gap_score"       - Primarily GAP score + category improvement
#   "gap_score_mech_fail" - GAP score + Mechanical Failure
#   "ll"              - Primarily PI-LL mismatch
#
# To add a new scenario: add an entry to runs.PRESETS in src/runs.py,
# then include its key here.

SCENARIOS = ["equal", "mech_fail", "mech_fail_t4l1pa", "l4s1", "t4l1pa", "gap_score", "gap_score_mech_fail", "ll", "odi"]

# Show selected scenarios
for key in SCENARIOS:
    runs.print_preset(runs.PRESETS[key])
# Out:
# ============================================================
#   Equal Weights (Composite)
#   All 6 alignment components and mechanical failure weighted equally
# ============================================================
#                        GAP Score: 0.1429 ◀
#                     L1PA penalty: 0.1429 ◀
#                     L4S1 penalty: 0.1429 ◀
#                   T4L1PA penalty: 0.1429 ◀
#                       LL penalty: 0.1429 ◀
#         GAP category improvement: 0.1429 ◀
#          Mechanical failure prob: 0.1429 ◀
#
# ============================================================
#   Minimize Mechanical Failure
#   Primarily mechanical failure probability, with small alignment weights
# ============================================================
#                        GAP Score: 0.0500 ◀
#                     L1PA penalty: 0.0500 ◀
#                     L4S1 penalty: 0.0500 ◀
#                   T4L1PA penalty: 0.0500 ◀
#                       LL penalty: 0.0500 ◀
#         GAP category improvement: 0.0500 ◀
#          Mechanical failure prob: 0.7000 ◀
#
# ============================================================
#   Minimize Mechanical Failure + T4L1PA
#   Mechanical failure probability and T4PA-L1PA mismatch weighted equally
# ============================================================
#                        GAP Score: 0.0000
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.0000
#                   T4L1PA penalty: 0.5000 ◀
#                       LL penalty: 0.0000
#         GAP category improvement: 0.0000
#          Mechanical failure prob: 0.5000 ◀
#
# ============================================================
#   Minimize L4S1 Penalty
#   Primarily L4-S1 in ideal range (35-45°), with mech failure guard
# ============================================================
#                        GAP Score: 0.0000
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.8000 ◀
#                   T4L1PA penalty: 0.0000
#                       LL penalty: 0.0000
#         GAP category improvement: 0.0000
#          Mechanical failure prob: 0.2000 ◀
#
# ============================================================
#   Minimize T4L1PA Penalty
#   Primarily T4PA-L1PA mismatch, with mech failure guard
# ============================================================
#                        GAP Score: 0.0000
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.0000
#                   T4L1PA penalty: 0.8000 ◀
#                       LL penalty: 0.0000
#         GAP category improvement: 0.0000
#          Mechanical failure prob: 0.2000 ◀
#
# ============================================================
#   Minimize GAP Score
#   Primarily overall GAP alignment score and category improvement, with mech failure guard
# ============================================================
#                        GAP Score: 0.5000 ◀
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.0000
#                   T4L1PA penalty: 0.0000
#                       LL penalty: 0.0000
#         GAP category improvement: 0.3000 ◀
#          Mechanical failure prob: 0.2000 ◀
#
# ============================================================
#   Minimize GAP Score and Mechanical Failure
#   Primarily overall GAP alignment score and category improvement, with mech failure guard
# ============================================================
#                        GAP Score: 0.4000 ◀
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.0000
#                   T4L1PA penalty: 0.0000
#                       LL penalty: 0.0000
#         GAP category improvement: 0.1000 ◀
#          Mechanical failure prob: 0.5000 ◀
#
# ============================================================
#   Minimize LL (PI-LL) Penalty
#   Primarily PI-LL mismatch, with mech failure guard
# ============================================================
#                        GAP Score: 0.0000
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.0000
#                   T4L1PA penalty: 0.0000
#                       LL penalty: 0.8000 ◀
#         GAP category improvement: 0.0000
#          Mechanical failure prob: 0.2000 ◀
#
# ============================================================
#   Minimize Postop ODI
#   Primarily lowest predicted postoperative ODI, with mech failure guard
# ============================================================
#                        GAP Score: 0.0000
#                     L1PA penalty: 0.0000
#                     L4S1 penalty: 0.0000
#                   T4L1PA penalty: 0.0000
#                       LL penalty: 0.0000
#         GAP category improvement: 0.0000
#          Mechanical failure prob: 0.2000 ◀
#                       ODI postop: 0.8000 ◀

# %%
UIV_CHOICES, xl, xu = ou.get_decision_config()

print("UIV_CHOICES:", UIV_CHOICES)
print("xl:", xl)
print("xu:", xu)

# Use column names from config
print(pd.DataFrame([xl, xu], index=["xl","xu"], columns=config.DECISION_VAR_NAMES))
# Out:
# UIV_CHOICES: ['Hook', 'PS', 'FS']
# xl: [0 0 0 0 0 0 1 2 0]
# xu: [2 1 5 1 1 1 6 4 1]
#     uiv_code  num_levels_cat_code  num_interbody_fusion_levels  ALIF  XLIF  \
# xl         0                    0                            0     0     0
# xu         2                    1                            5     1     1
#
#     TLIF  num_rods  num_pelvic_screws  osteotomy
# xl     0         1                  2          0
# xu     1         6                  4          1

# %% [markdown]
# ## Test Patient w fixed parameters

# %%
# Show holdout patients summary
holdout_df = pd.read_csv(config.DATA_HOLDOUT)

summary_cols = [
    'sex', 'age', 'ASA_CLASS',
    "id", "description", "revision", "mech_fail_last",
    "gap_score_preop", "gap_category", "gap_score_postop", "gap_category_postop",
    "UIV_implant", "num_levels_cat", "num_interbody_fusion_levels",
    "ALIF", "XLIF", "TLIF", "num_rods", "num_pelvic_screws", "osteotomy",
    "ODI_preop"
]
display(holdout_df[summary_cols].set_index("id"))

# Select patient
PATIENT_ID = 6380632
# PATIENT_ID = 2964021  # patient with ODI
patient_fixed = ou.load_patient_data(patient_id=PATIENT_ID, data_path=config.DATA_HOLDOUT)
print(f"\nSelected patient: {PATIENT_ID}")
# Out:
#             sex  age  ASA_CLASS                            description  \
# id
# 818588     MALE   78        2.0  mech failure - small GAP improvement;
# 1176294    MALE   71        NaN  mech failure - large GAP improvement;
# 2964021  FEMALE   70        3.0      revision - GAP improvement 3 to 1
# 6380632  FEMALE   76        3.0                 large GAP imporovement
#
#          revision  mech_fail_last  gap_score_preop gap_category  \
# id
# 818588          0             1.0             12.0           SD
# 1176294         0             1.0             10.0           SD
# 2964021         0             0.0              3.0           MD
# 6380632         0             0.0             12.0           SD
#
#          gap_score_postop gap_category_postop UIV_implant num_levels_cat  \
# id
# 818588               10.0                  SD          PS          lower
# 1176294               1.0                   P          FS          lower
# 2964021               1.0                   P          PS          lower
# 6380632               1.0                   P        Hook         higher
#
#          num_interbody_fusion_levels  ALIF  XLIF  TLIF  num_rods  \
# id
# 818588                             1     0     0     1         3
# 1176294                            1     1     1     0         4
# 2964021                            2     1     0     0         3
# 6380632                            2     1     0     0         3
#
#          num_pelvic_screws  osteotomy  ODI_preop
# id
# 818588                   2          0        NaN
# 1176294                  2          1        NaN
# 2964021                  3          0       15.0
# 6380632                  2          0        NaN
# Selected patient: 6380632

# %% [markdown]
# ## Run All Scenarios
#
# For each selected scenario, runs the GA optimizer and collects results.
#
# **Constraints (all scenarios):**
# - If `num_interbody_fusion_levels > 0`, at least one fusion type (`ALIF`, `XLIF`, or `TLIF`) must be selected.
# - If `ALIF=1` and `XLIF=0` and `TLIF=0`, then `num_interbody_fusion_levels` must be < 4.

# %%
# Run all selected scenarios
all_results = {}

for key in SCENARIOS:
    preset = runs.PRESETS[key]
    print(f"\n▶ Running: {preset['label']}...")

    result = runs.run_optimization(
        preset=preset,
        patient_fixed=patient_fixed,
        delta_bundles=delta_bundles,
        mech_fail_bundle=mech_fail_bundle,
        xl=xl,
        xu=xu,
        odi_bundle=ODI_bundle,
        pop_size=100,
        n_gen=20,
        seed=42,
        verbose=False,
        top_n=4,
        score_tolerance=2,
    )
    all_results[key] = result
    print(f"  ✓ Best composite: {result['best_result']['composite_score']:.2f}"
          f"  |  Mech fail: {result['best_result']['mech_fail_prob']*100:.1f}%")

print(f"\n{'='*60}")
print(f"Completed {len(all_results)} scenarios.")
# Out:
# ▶ Running: Equal Weights (Composite)...
#   ✓ Best composite: 4.71  |  Mech fail: 16.5%
#
# ▶ Running: Minimize Mechanical Failure...
#   ✓ Best composite: 7.33  |  Mech fail: 9.3%
#
# ▶ Running: Minimize Mechanical Failure + T4L1PA...
#   ✓ Best composite: 1.00  |  Mech fail: 2.0%
#
# ▶ Running: Minimize L4S1 Penalty...
#   ✓ Best composite: 0.47  |  Mech fail: 2.4%
#
# ▶ Running: Minimize T4L1PA Penalty...
#   ✓ Best composite: 0.40  |  Mech fail: 2.0%
#
# ▶ Running: Minimize GAP Score...
#   ✓ Best composite: 10.45  |  Mech fail: 13.8%
#
# ▶ Running: Minimize GAP Score and Mechanical Failure...
#   ✓ Best composite: 13.05  |  Mech fail: 13.8%
#
# ▶ Running: Minimize LL (PI-LL) Penalty...
#   ✓ Best composite: 1.79  |  Mech fail: 4.9%
#
# ▶ Running: Minimize Postop ODI...
#   ✓ Best composite: 0.40  |  Mech fail: 2.0%
#
# ============================================================
# Completed 9 scenarios.

# %% [markdown]
# ## Actual surgical plan & outcome for comparison

# %%
df_actual = disp.display_actual_outcomes(
    PATIENT_ID, patient_fixed, data_path=config.DATA_HOLDOUT,
    delta_bundles=delta_bundles,
    mech_fail_bundle=mech_fail_bundle,
    odi_bundle=ODI_bundle,
    presets=runs.PRESETS,
)
display(df_actual)
# Out:
# ============================================================
# ACTUAL SURGICAL PLAN (WHAT WAS PERFORMED)
# ============================================================
#   UIV_implant: Hook
#   num_levels_cat: higher
#   num_interbody_fusion_levels: 2
#   ALIF: 1
#   XLIF: 0
#   TLIF: 0
#   num_rods: 3
#   num_pelvic_screws: 2
#   osteotomy (PSO): 0
#
#   Mechanical Failure: No
#   ODI: N/A (preop) → N/A (12mo)
#
# ============================================================
# MODEL SCORES FOR ACTUAL PLAN
# ============================================================
#   Mech Failure Prob (predicted): 42.7%
#
#   Scenario Scores (lower is better):
#     [equal]                Equal Weights (Composite)                   16.00
#     [mech_fail]            Minimize Mechanical Failure                 33.34
#     [mech_fail_t4l1pa]     Minimize Mechanical Failure + T4L1PA        21.34
#     [l4s1]                 Minimize L4S1 Penalty                        8.54
#     [t4l1pa]               Minimize T4L1PA Penalty                      8.54
#     [equal_plus_mech]      Equal Alignment + Mechanical Failure        27.12
#     [odi]                  Minimize Postop ODI                          8.54
#     [gap_score]            Minimize GAP Score                          36.77
#     [gap_score_mech_fail]  Minimize GAP Score and Mechanical Failure   39.72
#     [ll]                   Minimize LL (PI-LL) Penalty                  9.23
#
# ============================================================
# ALIGNMENT PARAMETERS: PREOP → POSTOP (ACTUAL)
# ============================================================
#               Parameter    Preop Delta (actual) Postop (actual)
# 0                    LL     30.4           32.5            62.9
# 1                    SS     33.8           11.5            45.3
# 2                  L4S1     34.5            7.0            41.5
# 3            GlobalTilt     42.2          -23.9            18.3
# 4                  T4PA     24.8          -15.2             9.6
# 5                  L1PA     12.2           -4.8             7.4
# 6                    PI     58.6            2.2            60.8
# 7                    PT     24.8           -9.3            15.5
# 8                   SVA    154.6         -124.8            29.8
# 9                   Age       76              -               -
# 10            GAP Score     12.0              -             1.0
# 11         GAP Category       SD              →               P
# 12  ─── CONSTRAINTS ───
# 13         PI-LL (0–10)   28.2 ⚠          -30.3          -2.1 ⚠
# 14   L1PA−ideal (|d|≤3)    3.9 ⚠           -4.8          -0.9 ✓
# 15         L4S1 (35–45)   34.5 ⚠            7.0          41.5 ✓
# 16    T4PA−L1PA (|d|≤3)   12.6 ⚠          -10.4           2.2 ✓
# 17     LL−ideal (|d|≤3)  -28.8 ⚠           32.5           3.7 ⚠
# 18          GAP Cat (P)     SD ⚠              →             P ✓

# %% [markdown]
# ## Results per Scenario

# %%
from IPython.display import display, Markdown

for key in SCENARIOS:
    r = all_results[key]

    display(Markdown(f"### {r['label']}"))
    display(Markdown(f"*{runs.PRESETS[key]['description']}*"))

    # # Best solution
    # df_comparison = disp.display_optimized_solution(r["best_result"], patient_fixed)
    # display(df_comparison)

    # Top 4 diverse plans
    display(Markdown("**Top diverse plans:**"))
    _ = disp.display_multiple_solutions(r["diverse_df"], patient_fixed)
# Out:
# ### Equal Weights (Composite)
# *All 6 alignment components and mechanical failure weighted equally*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                 1.6                 2.8
# 1            Optimization Score                 2.1                 2.8
# 2                Mech Fail Prob                5.1%                2.7%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score   12.0 (SD) → 1 (P)   12.0 (SD) → 2 (P)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                Hook
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   4                   5
# 10                         ALIF                   0                   0
# 11                         XLIF                   1                   0
# 12                         TLIF                   0                   1
# 13                     num_rods                   5                   2
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.4
# 19                           SS                41.7                42.8
# 20                         L4S1                40.3                40.8
# 21                   GlobalTilt                22.5                24.0
# 22                         T4PA                 0.3                 0.5
# 23                         L1PA                 1.3                 2.6
# 24                          SVA                95.2                86.6
# 25                           PI                58.6                58.6
# 26                           PT                16.9                15.8
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.2 ✓
# 30           L1PA−ideal (|d|≤3)              -7.0 ⚠              -5.7 ⚠
# 31                 L4S1 (35–45)              40.3 ✓              40.8 ✓
# 32            T4PA−L1PA (|d|≤3)              -1.0 ✓              -2.1 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -7.8 ⚠
# 34             GAP Category (P)                 P ✓                 P ✓
#
#                  Sol 3               Sol 4
# 0                  1.5                 1.6
# 1                  3.2                 3.3
# 2                12.9%               13.6%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4    12.0 (SD) → 1 (P)   12.0 (SD) → 1 (P)
# 5           ──────────          ──────────
# 6
# 7                 Hook                  FS
# 8               higher               lower
# 9                    4                   4
# 10                   0                   0
# 11                   1                   1
# 12                   0                   0
# 13                   4                   5
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.0
# 19                41.7                41.3
# 20                39.7                38.2
# 21                23.1                22.6
# 22                 0.4                 0.5
# 23                 1.8                 0.6
# 24                95.0               103.8
# 25                58.6                58.6
# 26                16.9                17.3
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.6 ✓
# 30              -6.5 ⚠              -7.7 ⚠
# 31              39.7 ✓              38.2 ✓
# 32              -1.4 ✓              -0.1 ✓
# 33              -8.1 ⚠              -8.2 ⚠
# 34                 P ✓                 P ✓
# ### Minimize Mechanical Failure
# *Primarily mechanical failure probability, with small alignment weights*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                 2.8                 2.8
# 1            Optimization Score                 2.7                 3.1
# 2                Mech Fail Prob                2.7%                3.2%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score   12.0 (SD) → 2 (P)   12.0 (SD) → 2 (P)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                Hook
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   5
# 10                         ALIF                   0                   0
# 11                         XLIF                   0                   0
# 12                         TLIF                   1                   1
# 13                     num_rods                   2                   1
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.4                51.4
# 19                           SS                42.8                42.8
# 20                         L4S1                40.8                39.2
# 21                   GlobalTilt                24.0                24.0
# 22                         T4PA                 0.5                 0.8
# 23                         L1PA                 2.6                 3.1
# 24                          SVA                86.6                86.6
# 25                           PI                58.6                58.6
# 26                           PT                15.8                15.8
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.2 ✓               7.2 ✓
# 30           L1PA−ideal (|d|≤3)              -5.7 ⚠              -5.2 ⚠
# 31                 L4S1 (35–45)              40.8 ✓              39.2 ✓
# 32            T4PA−L1PA (|d|≤3)              -2.1 ✓              -2.3 ✓
# 33             LL−ideal (|d|≤3)              -7.8 ⚠              -7.8 ⚠
# 34             GAP Category (P)                 P ✓                 P ✓
#
#                  Sol 3               Sol 4
# 0                  2.8                 2.7
# 1                  3.1                 3.6
# 2                 3.3%                3.9%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4    12.0 (SD) → 2 (P)   12.0 (SD) → 2 (P)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower               lower
# 9                    4                   4
# 10                   0                   0
# 11                   0                   0
# 12                   1                   1
# 13                   2                   1
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.4                51.4
# 19                42.8                42.8
# 20                40.6                38.9
# 21                23.8                23.8
# 22                 1.4                 1.7
# 23                 3.1                 3.6
# 24                86.6                86.6
# 25                58.6                58.6
# 26                15.8                15.8
# 27          ──────────          ──────────
# 28
# 29               7.2 ✓               7.2 ✓
# 30              -5.2 ⚠              -4.7 ⚠
# 31              40.6 ✓              38.9 ✓
# 32              -1.7 ✓              -1.9 ✓
# 33              -7.8 ⚠              -7.8 ⚠
# 34                 P ✓                 P ✓
# ### Minimize Mechanical Failure + T4L1PA
# *Mechanical failure probability and T4PA-L1PA mismatch weighted equally*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                10.5                10.6
# 1            Optimization Score                 0.7                 1.4
# 2                Mech Fail Prob                1.4%                2.7%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score  12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                  PS
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   5
# 10                         ALIF                   0                   0
# 11                         XLIF                   0                   0
# 12                         TLIF                   1                   1
# 13                     num_rods                   6                   6
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.0
# 19                           SS                42.0                41.7
# 20                         L4S1                47.4                49.0
# 21                   GlobalTilt                22.7                22.7
# 22                         T4PA                -0.6                -0.9
# 23                         L1PA                 0.6                -0.5
# 24                          SVA                86.7                82.5
# 25                           PI                58.6                58.6
# 26                           PT                16.6                16.9
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.6 ✓
# 30           L1PA−ideal (|d|≤3)              -7.7 ⚠              -8.8 ⚠
# 31                 L4S1 (35–45)              47.4 ⚠              49.0 ⚠
# 32            T4PA−L1PA (|d|≤3)              -1.2 ✓              -0.4 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.2 ⚠
# 34             GAP Category (P)                MD ⚠                MD ⚠
#
#                  Sol 3               Sol 4
# 0                 10.4                10.5
# 1                  1.7                 1.9
# 2                 3.3%                3.8%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4   12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower              higher
# 9                    4                   4
# 10                   0                   0
# 11                   1                   0
# 12                   1                   1
# 13                   6                   6
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.1
# 19                41.8                42.0
# 20                46.3                48.3
# 21                22.5                22.5
# 22                 1.3                 0.1
# 23                 1.4                 1.1
# 24                92.6                86.9
# 25                58.6                58.6
# 26                16.8                16.6
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.5 ✓
# 30              -6.9 ⚠              -7.2 ⚠
# 31              46.3 ⚠              48.3 ⚠
# 32              -0.1 ✓              -1.0 ✓
# 33              -8.1 ⚠              -8.1 ⚠
# 34                MD ⚠                MD ⚠
# ### Minimize L4S1 Penalty
# *Primarily L4-S1 in ideal range (35-45°), with mech failure guard*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                10.4                10.5
# 1            Optimization Score                 0.3                 0.9
# 2                Mech Fail Prob                1.6%                4.0%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score  12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                  PS
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   4
# 10                         ALIF                   0                   0
# 11                         XLIF                   0                   0
# 12                         TLIF                   1                   1
# 13                     num_rods                   5                   5
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.0
# 19                           SS                41.9                41.6
# 20                         L4S1                45.8                47.2
# 21                   GlobalTilt                22.7                22.5
# 22                         T4PA                -0.3                 0.3
# 23                         L1PA                 1.1                 0.5
# 24                          SVA                89.3                85.2
# 25                           PI                58.6                58.6
# 26                           PT                16.7                17.0
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.6 ✓
# 30           L1PA−ideal (|d|≤3)              -7.2 ⚠              -7.8 ⚠
# 31                 L4S1 (35–45)              45.8 ⚠              47.2 ⚠
# 32            T4PA−L1PA (|d|≤3)              -1.4 ✓              -0.2 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.2 ⚠
# 34             GAP Category (P)                MD ⚠                MD ⚠
#
#                  Sol 3               Sol 4
# 0                 10.3                10.5
# 1                  1.1                 1.2
# 2                 5.7%                6.0%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4   12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5           ──────────          ──────────
# 6
# 7                 Hook                  FS
# 8                lower               lower
# 9                    3                   5
# 10                   0                   0
# 11                   1                   0
# 12                   1                   1
# 13                   4                   5
# 14                   2                   3
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.0
# 19                41.7                41.5
# 20                42.7                44.4
# 21                23.1                22.6
# 22                 2.7                -0.7
# 23                 2.9                -0.2
# 24                89.5                98.3
# 25                58.6                58.6
# 26                16.9                17.1
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.6 ✓
# 30              -5.4 ⚠              -8.5 ⚠
# 31              42.7 ✓              44.4 ✓
# 32              -0.2 ✓              -0.5 ✓
# 33              -8.1 ⚠              -8.2 ⚠
# 34                MD ⚠                MD ⚠
# ### Minimize T4L1PA Penalty
# *Primarily T4PA-L1PA mismatch, with mech failure guard*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                10.5                10.6
# 1            Optimization Score                 0.3                 0.6
# 2                Mech Fail Prob                1.4%                2.7%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score  12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                  PS
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   5
# 10                         ALIF                   0                   0
# 11                         XLIF                   0                   0
# 12                         TLIF                   1                   1
# 13                     num_rods                   6                   6
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.0
# 19                           SS                42.0                41.7
# 20                         L4S1                47.4                49.0
# 21                   GlobalTilt                22.7                22.7
# 22                         T4PA                -0.6                -0.9
# 23                         L1PA                 0.6                -0.5
# 24                          SVA                86.7                82.5
# 25                           PI                58.6                58.6
# 26                           PT                16.6                16.9
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.6 ✓
# 30           L1PA−ideal (|d|≤3)              -7.7 ⚠              -8.8 ⚠
# 31                 L4S1 (35–45)              47.4 ⚠              49.0 ⚠
# 32            T4PA−L1PA (|d|≤3)              -1.2 ✓              -0.4 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.2 ⚠
# 34             GAP Category (P)                MD ⚠                MD ⚠
#
#                  Sol 3               Sol 4
# 0                 10.4                10.5
# 1                  0.7                 0.8
# 2                 3.3%                3.8%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4   12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower              higher
# 9                    4                   4
# 10                   0                   0
# 11                   1                   0
# 12                   1                   1
# 13                   6                   6
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.1
# 19                41.8                42.0
# 20                46.3                48.3
# 21                22.5                22.5
# 22                 1.3                 0.1
# 23                 1.4                 1.1
# 24                92.6                86.9
# 25                58.6                58.6
# 26                16.8                16.6
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.5 ✓
# 30              -6.9 ⚠              -7.2 ⚠
# 31              46.3 ⚠              48.3 ⚠
# 32              -0.1 ✓              -1.0 ✓
# 33              -8.1 ⚠              -8.1 ⚠
# 34                MD ⚠                MD ⚠
# ### Minimize GAP Score
# *Primarily overall GAP alignment score and category improvement, with mech failure guard*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                 1.6                 1.6
# 1            Optimization Score                 4.7                 4.9
# 2                Mech Fail Prob                4.1%                5.1%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score   12.0 (SD) → 1 (P)   12.0 (SD) → 1 (P)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                Hook
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   4
# 10                         ALIF                   0                   0
# 11                         XLIF                   1                   1
# 12                         TLIF                   0                   0
# 13                     num_rods                   5                   5
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.1
# 19                           SS                41.7                41.7
# 20                         L4S1                40.5                40.3
# 21                   GlobalTilt                22.7                22.5
# 22                         T4PA                -0.6                 0.3
# 23                         L1PA                 0.8                 1.3
# 24                          SVA                95.2                95.2
# 25                           PI                58.6                58.6
# 26                           PT                16.9                16.9
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.5 ✓
# 30           L1PA−ideal (|d|≤3)              -7.5 ⚠              -7.0 ⚠
# 31                 L4S1 (35–45)              40.5 ✓              40.3 ✓
# 32            T4PA−L1PA (|d|≤3)              -1.4 ✓              -1.0 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.1 ⚠
# 34             GAP Category (P)                 P ✓                 P ✓
#
#                  Sol 3               Sol 4
# 0                  1.5                 1.5
# 1                  5.0                 5.3
# 2                 6.0%                7.3%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4    12.0 (SD) → 1 (P)   12.0 (SD) → 1 (P)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower               lower
# 9                    4                   3
# 10                   0                   0
# 11                   1                   1
# 12                   0                   0
# 13                   4                   4
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.1
# 19                41.7                41.7
# 20                38.6                38.4
# 21                23.1                23.1
# 22                 0.6                 1.5
# 23                 1.8                 2.3
# 24                94.8                89.5
# 25                58.6                58.6
# 26                16.9                16.9
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.5 ✓
# 30              -6.5 ⚠              -6.0 ⚠
# 31              38.6 ✓              38.4 ✓
# 32              -1.2 ✓              -0.8 ✓
# 33              -8.1 ⚠              -8.1 ⚠
# 34                 P ✓                 P ✓
# ### Minimize GAP Score and Mechanical Failure
# *Primarily overall GAP alignment score and category improvement, with mech failure guard*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                 1.6                 1.6
# 1            Optimization Score                 5.2                 5.6
# 2                Mech Fail Prob                4.1%                5.1%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score   12.0 (SD) → 1 (P)   12.0 (SD) → 1 (P)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                Hook
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   4
# 10                         ALIF                   0                   0
# 11                         XLIF                   1                   1
# 12                         TLIF                   0                   0
# 13                     num_rods                   5                   5
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.1
# 19                           SS                41.7                41.7
# 20                         L4S1                40.5                40.3
# 21                   GlobalTilt                22.7                22.5
# 22                         T4PA                -0.6                 0.3
# 23                         L1PA                 0.8                 1.3
# 24                          SVA                95.2                95.2
# 25                           PI                58.6                58.6
# 26                           PT                16.9                16.9
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.5 ✓
# 30           L1PA−ideal (|d|≤3)              -7.5 ⚠              -7.0 ⚠
# 31                 L4S1 (35–45)              40.5 ✓              40.3 ✓
# 32            T4PA−L1PA (|d|≤3)              -1.4 ✓              -1.0 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.1 ⚠
# 34             GAP Category (P)                 P ✓                 P ✓
#
#                  Sol 3               Sol 4
# 0                  1.5                 1.5
# 1                  6.1                 6.2
# 2                 6.0%                6.2%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4    12.0 (SD) → 1 (P)   12.0 (SD) → 1 (P)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower               lower
# 9                    4                   3
# 10                   0                   0
# 11                   1                   1
# 12                   0                   0
# 13                   4                   5
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.1
# 19                41.7                41.7
# 20                38.6                40.0
# 21                23.1                22.5
# 22                 0.6                 1.2
# 23                 1.8                 1.8
# 24                94.8                90.0
# 25                58.6                58.6
# 26                16.9                16.9
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.5 ✓
# 30              -6.5 ⚠              -6.5 ⚠
# 31              38.6 ✓              40.0 ✓
# 32              -1.2 ✓              -0.6 ✓
# 33              -8.1 ⚠              -8.1 ⚠
# 34                 P ✓                 P ✓
# ### Minimize LL (PI-LL) Penalty
# *Primarily PI-LL mismatch, with mech failure guard*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                10.5                10.5
# 1            Optimization Score                 1.1                 1.5
# 2                Mech Fail Prob                1.4%                3.2%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score  12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                  PS
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   5
# 10                         ALIF                   0                   0
# 11                         XLIF                   0                   0
# 12                         TLIF                   1                   1
# 13                     num_rods                   6                   5
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.0
# 19                           SS                42.0                41.6
# 20                         L4S1                47.4                47.4
# 21                   GlobalTilt                22.7                22.7
# 22                         T4PA                -0.6                -0.6
# 23                         L1PA                 0.6                 0.0
# 24                          SVA                86.7                85.2
# 25                           PI                58.6                58.6
# 26                           PT                16.6                17.0
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.6 ✓
# 30           L1PA−ideal (|d|≤3)              -7.7 ⚠              -8.3 ⚠
# 31                 L4S1 (35–45)              47.4 ⚠              47.4 ⚠
# 32            T4PA−L1PA (|d|≤3)              -1.2 ✓              -0.6 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.2 ⚠
# 34             GAP Category (P)                MD ⚠                MD ⚠
#
#                  Sol 3               Sol 4
# 0                 11.2                10.4
# 1                  1.6                 1.6
# 2                 4.3%                3.9%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4   12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower               lower
# 9                    4                   4
# 10                   1                   0
# 11                   0                   1
# 12                   1                   1
# 13                   5                   5
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.6                51.1
# 19                42.3                41.7
# 20                55.0                44.6
# 21                22.5                22.5
# 22                -0.6                 1.5
# 23                -0.5                 1.9
# 24                89.6                95.2
# 25                58.6                58.6
# 26                16.3                16.9
# 27          ──────────          ──────────
# 28
# 29               7.0 ✓               7.5 ✓
# 30              -8.8 ⚠              -6.4 ⚠
# 31              55.0 ⚠              44.6 ✓
# 32              -0.1 ✓              -0.4 ✓
# 33              -7.6 ⚠              -8.1 ⚠
# 34                MD ⚠                MD ⚠
# ### Minimize Postop ODI
# *Primarily lowest predicted postoperative ODI, with mech failure guard*
# **Top diverse plans:**
# ============================================================
# SOLUTIONS COMPARISON
# ============================================================
#                       Parameter               Sol 1               Sol 2  \
# 0               Alignment Score                10.5                10.6
# 1            Optimization Score                 0.3                 0.6
# 2                Mech Fail Prob                1.4%                2.7%
# 3                 Predicted ODI  N/A (no preop ODI)  N/A (no preop ODI)
# 4                     GAP Score  12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5                  ────────────          ──────────          ──────────
# 6                 SURGICAL PLAN
# 7                   UIV_implant                Hook                  PS
# 8                num_levels_cat               lower               lower
# 9   num_interbody_fusion_levels                   5                   5
# 10                         ALIF                   0                   0
# 11                         XLIF                   0                   0
# 12                         TLIF                   1                   1
# 13                     num_rods                   6                   6
# 14            num_pelvic_screws                   2                   2
# 15              osteotomy (PSO)                   1                   1
# 16                 ────────────          ──────────          ──────────
# 17                POSTOP VALUES
# 18                           LL                51.1                51.0
# 19                           SS                42.0                41.7
# 20                         L4S1                47.4                49.0
# 21                   GlobalTilt                22.7                22.7
# 22                         T4PA                -0.6                -0.9
# 23                         L1PA                 0.6                -0.5
# 24                          SVA                86.7                82.5
# 25                           PI                58.6                58.6
# 26                           PT                16.6                16.9
# 27                 ────────────          ──────────          ──────────
# 28                  CONSTRAINTS
# 29                 PI-LL (0–10)               7.5 ✓               7.6 ✓
# 30           L1PA−ideal (|d|≤3)              -7.7 ⚠              -8.8 ⚠
# 31                 L4S1 (35–45)              47.4 ⚠              49.0 ⚠
# 32            T4PA−L1PA (|d|≤3)              -1.2 ✓              -0.4 ✓
# 33             LL−ideal (|d|≤3)              -8.1 ⚠              -8.2 ⚠
# 34             GAP Category (P)                MD ⚠                MD ⚠
#
#                  Sol 3               Sol 4
# 0                 10.4                10.5
# 1                  0.7                 0.8
# 2                 3.3%                3.8%
# 3   N/A (no preop ODI)  N/A (no preop ODI)
# 4   12.0 (SD) → 4 (MD)  12.0 (SD) → 4 (MD)
# 5           ──────────          ──────────
# 6
# 7                 Hook                Hook
# 8                lower              higher
# 9                    4                   4
# 10                   0                   0
# 11                   1                   0
# 12                   1                   1
# 13                   6                   6
# 14                   2                   2
# 15                   1                   1
# 16          ──────────          ──────────
# 17
# 18                51.1                51.1
# 19                41.8                42.0
# 20                46.3                48.3
# 21                22.5                22.5
# 22                 1.3                 0.1
# 23                 1.4                 1.1
# 24                92.6                86.9
# 25                58.6                58.6
# 26                16.8                16.6
# 27          ──────────          ──────────
# 28
# 29               7.5 ✓               7.5 ✓
# 30              -6.9 ⚠              -7.2 ⚠
# 31              46.3 ⚠              48.3 ⚠
# 32              -0.1 ✓              -1.0 ✓
# 33              -8.1 ⚠              -8.1 ⚠
# 34                MD ⚠                MD ⚠

# %% [markdown]
# ## Actual vs. Optimized Plans per Scenario
#
# For each scenario, the **Actual** column (highlighted) shows the real surgical plan scored with that scenario's weights. The remaining columns show the optimizer's top diverse recommendations.

# %%
# Build x vector for the actual surgical plan (from holdout data)
holdout_row = holdout_df[holdout_df["id"] == PATIENT_ID].iloc[0]
actual_x = []
for var_spec in config.DECISION_VAR_SPECS:
    col = var_spec["col_name"]
    val = holdout_row[col]
    if var_spec.get("categorical", False):
        actual_x.append(var_spec["choices"].index(val))
    else:
        actual_x.append(int(val))
actual_x = np.array(actual_x)

# Display each scenario: actual plan (highlighted) + top diverse optimized plans
for key in SCENARIOS:
    r = all_results[key]
    preset = runs.PRESETS[key]
    weights = preset["weights"]

    # Evaluate the actual plan with this scenario's weights
    actual_eval = ou.evaluate_solution(
        actual_x, patient_fixed, delta_bundles, mech_fail_bundle,
        weights=weights, odi_bundle=ODI_bundle
    )

    display(Markdown(f"### {r['label']}"))
    display(Markdown(f"*{preset['description']}*"))
    disp.display_solutions_with_actual(r["diverse_df"], patient_fixed, actual_eval)
# Out:
# ### Equal Weights (Composite)
# *All 6 alignment components and mechanical failure weighted equally*
# <style type="text/css">
# #T_7f1d1_row0_col1, #T_7f1d1_row1_col1, #T_7f1d1_row2_col1, #T_7f1d1_row3_col1, #T_7f1d1_row4_col1, #T_7f1d1_row5_col1, #T_7f1d1_row6_col1, #T_7f1d1_row7_col1, #T_7f1d1_row8_col1, #T_7f1d1_row9_col1, #T_7f1d1_row10_col1, #T_7f1d1_row11_col1, #T_7f1d1_row12_col1, #T_7f1d1_row13_col1, #T_7f1d1_row14_col1, #T_7f1d1_row15_col1, #T_7f1d1_row16_col1, #T_7f1d1_row17_col1, #T_7f1d1_row18_col1, #T_7f1d1_row19_col1, #T_7f1d1_row20_col1, #T_7f1d1_row21_col1, #T_7f1d1_row22_col1, #T_7f1d1_row23_col1, #T_7f1d1_row24_col1, #T_7f1d1_row25_col1, #T_7f1d1_row26_col1, #T_7f1d1_row27_col1, #T_7f1d1_row28_col1, #T_7f1d1_row29_col1, #T_7f1d1_row30_col1, #T_7f1d1_row31_col1, #T_7f1d1_row32_col1, #T_7f1d1_row33_col1, #T_7f1d1_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_7f1d1">
#   <thead>
#     <tr>
#       <th id="T_7f1d1_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_7f1d1_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_7f1d1_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_7f1d1_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_7f1d1_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_7f1d1_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f1d1_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_7f1d1_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_7f1d1_row0_col2" class="data row0 col2" >1.6</td>
#       <td id="T_7f1d1_row0_col3" class="data row0 col3" >2.8</td>
#       <td id="T_7f1d1_row0_col4" class="data row0 col4" >1.5</td>
#       <td id="T_7f1d1_row0_col5" class="data row0 col5" >1.6</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_7f1d1_row1_col1" class="data row1 col1" >16.0</td>
#       <td id="T_7f1d1_row1_col2" class="data row1 col2" >2.1</td>
#       <td id="T_7f1d1_row1_col3" class="data row1 col3" >2.8</td>
#       <td id="T_7f1d1_row1_col4" class="data row1 col4" >3.2</td>
#       <td id="T_7f1d1_row1_col5" class="data row1 col5" >3.3</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_7f1d1_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_7f1d1_row2_col2" class="data row2 col2" >5.1%</td>
#       <td id="T_7f1d1_row2_col3" class="data row2 col3" >2.7%</td>
#       <td id="T_7f1d1_row2_col4" class="data row2 col4" >12.9%</td>
#       <td id="T_7f1d1_row2_col5" class="data row2 col5" >13.6%</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_7f1d1_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_7f1d1_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_7f1d1_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_7f1d1_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_7f1d1_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_7f1d1_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_7f1d1_row4_col2" class="data row4 col2" >12.0 (SD) → 1 (P)</td>
#       <td id="T_7f1d1_row4_col3" class="data row4 col3" >12.0 (SD) → 2 (P)</td>
#       <td id="T_7f1d1_row4_col4" class="data row4 col4" >12.0 (SD) → 1 (P)</td>
#       <td id="T_7f1d1_row4_col5" class="data row4 col5" >12.0 (SD) → 1 (P)</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_7f1d1_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_7f1d1_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_7f1d1_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_7f1d1_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_7f1d1_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_7f1d1_row6_col1" class="data row6 col1" ></td>
#       <td id="T_7f1d1_row6_col2" class="data row6 col2" ></td>
#       <td id="T_7f1d1_row6_col3" class="data row6 col3" ></td>
#       <td id="T_7f1d1_row6_col4" class="data row6 col4" ></td>
#       <td id="T_7f1d1_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_7f1d1_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_7f1d1_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_7f1d1_row7_col3" class="data row7 col3" >Hook</td>
#       <td id="T_7f1d1_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_7f1d1_row7_col5" class="data row7 col5" >FS</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_7f1d1_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_7f1d1_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_7f1d1_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_7f1d1_row8_col4" class="data row8 col4" >higher</td>
#       <td id="T_7f1d1_row8_col5" class="data row8 col5" >lower</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_7f1d1_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_7f1d1_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_7f1d1_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_7f1d1_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_7f1d1_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_7f1d1_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_7f1d1_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_7f1d1_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_7f1d1_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_7f1d1_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_7f1d1_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_7f1d1_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_7f1d1_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_7f1d1_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_7f1d1_row11_col5" class="data row11 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_7f1d1_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_7f1d1_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_7f1d1_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_7f1d1_row12_col4" class="data row12 col4" >0</td>
#       <td id="T_7f1d1_row12_col5" class="data row12 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_7f1d1_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_7f1d1_row13_col2" class="data row13 col2" >5</td>
#       <td id="T_7f1d1_row13_col3" class="data row13 col3" >2</td>
#       <td id="T_7f1d1_row13_col4" class="data row13 col4" >4</td>
#       <td id="T_7f1d1_row13_col5" class="data row13 col5" >5</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_7f1d1_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_7f1d1_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_7f1d1_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_7f1d1_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_7f1d1_row14_col5" class="data row14 col5" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7f1d1_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_7f1d1_row15_col1" class="data row15 col1" >0</td>
#       <td i
# ### Minimize Mechanical Failure
# *Primarily mechanical failure probability, with small alignment weights*
# <style type="text/css">
# #T_7952e_row0_col1, #T_7952e_row1_col1, #T_7952e_row2_col1, #T_7952e_row3_col1, #T_7952e_row4_col1, #T_7952e_row5_col1, #T_7952e_row6_col1, #T_7952e_row7_col1, #T_7952e_row8_col1, #T_7952e_row9_col1, #T_7952e_row10_col1, #T_7952e_row11_col1, #T_7952e_row12_col1, #T_7952e_row13_col1, #T_7952e_row14_col1, #T_7952e_row15_col1, #T_7952e_row16_col1, #T_7952e_row17_col1, #T_7952e_row18_col1, #T_7952e_row19_col1, #T_7952e_row20_col1, #T_7952e_row21_col1, #T_7952e_row22_col1, #T_7952e_row23_col1, #T_7952e_row24_col1, #T_7952e_row25_col1, #T_7952e_row26_col1, #T_7952e_row27_col1, #T_7952e_row28_col1, #T_7952e_row29_col1, #T_7952e_row30_col1, #T_7952e_row31_col1, #T_7952e_row32_col1, #T_7952e_row33_col1, #T_7952e_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_7952e">
#   <thead>
#     <tr>
#       <th id="T_7952e_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_7952e_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_7952e_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_7952e_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_7952e_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_7952e_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7952e_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_7952e_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_7952e_row0_col2" class="data row0 col2" >2.8</td>
#       <td id="T_7952e_row0_col3" class="data row0 col3" >2.8</td>
#       <td id="T_7952e_row0_col4" class="data row0 col4" >2.8</td>
#       <td id="T_7952e_row0_col5" class="data row0 col5" >2.7</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_7952e_row1_col1" class="data row1 col1" >33.3</td>
#       <td id="T_7952e_row1_col2" class="data row1 col2" >2.7</td>
#       <td id="T_7952e_row1_col3" class="data row1 col3" >3.1</td>
#       <td id="T_7952e_row1_col4" class="data row1 col4" >3.1</td>
#       <td id="T_7952e_row1_col5" class="data row1 col5" >3.6</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_7952e_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_7952e_row2_col2" class="data row2 col2" >2.7%</td>
#       <td id="T_7952e_row2_col3" class="data row2 col3" >3.2%</td>
#       <td id="T_7952e_row2_col4" class="data row2 col4" >3.3%</td>
#       <td id="T_7952e_row2_col5" class="data row2 col5" >3.9%</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_7952e_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_7952e_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_7952e_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_7952e_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_7952e_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_7952e_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_7952e_row4_col2" class="data row4 col2" >12.0 (SD) → 2 (P)</td>
#       <td id="T_7952e_row4_col3" class="data row4 col3" >12.0 (SD) → 2 (P)</td>
#       <td id="T_7952e_row4_col4" class="data row4 col4" >12.0 (SD) → 2 (P)</td>
#       <td id="T_7952e_row4_col5" class="data row4 col5" >12.0 (SD) → 2 (P)</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_7952e_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_7952e_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_7952e_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_7952e_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_7952e_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_7952e_row6_col1" class="data row6 col1" ></td>
#       <td id="T_7952e_row6_col2" class="data row6 col2" ></td>
#       <td id="T_7952e_row6_col3" class="data row6 col3" ></td>
#       <td id="T_7952e_row6_col4" class="data row6 col4" ></td>
#       <td id="T_7952e_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_7952e_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_7952e_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_7952e_row7_col3" class="data row7 col3" >Hook</td>
#       <td id="T_7952e_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_7952e_row7_col5" class="data row7 col5" >Hook</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_7952e_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_7952e_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_7952e_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_7952e_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_7952e_row8_col5" class="data row8 col5" >lower</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_7952e_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_7952e_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_7952e_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_7952e_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_7952e_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_7952e_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_7952e_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_7952e_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_7952e_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_7952e_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_7952e_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_7952e_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_7952e_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_7952e_row11_col4" class="data row11 col4" >0</td>
#       <td id="T_7952e_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_7952e_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_7952e_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_7952e_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_7952e_row12_col4" class="data row12 col4" >1</td>
#       <td id="T_7952e_row12_col5" class="data row12 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_7952e_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_7952e_row13_col2" class="data row13 col2" >2</td>
#       <td id="T_7952e_row13_col3" class="data row13 col3" >1</td>
#       <td id="T_7952e_row13_col4" class="data row13 col4" >2</td>
#       <td id="T_7952e_row13_col5" class="data row13 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_7952e_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_7952e_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_7952e_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_7952e_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_7952e_row14_col5" class="data row14 col5" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7952e_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_7952e_row15_col1" class="data row15 col1" >0</td>
#       <td id
# ### Minimize Mechanical Failure + T4L1PA
# *Mechanical failure probability and T4PA-L1PA mismatch weighted equally*
# <style type="text/css">
# #T_3104a_row0_col1, #T_3104a_row1_col1, #T_3104a_row2_col1, #T_3104a_row3_col1, #T_3104a_row4_col1, #T_3104a_row5_col1, #T_3104a_row6_col1, #T_3104a_row7_col1, #T_3104a_row8_col1, #T_3104a_row9_col1, #T_3104a_row10_col1, #T_3104a_row11_col1, #T_3104a_row12_col1, #T_3104a_row13_col1, #T_3104a_row14_col1, #T_3104a_row15_col1, #T_3104a_row16_col1, #T_3104a_row17_col1, #T_3104a_row18_col1, #T_3104a_row19_col1, #T_3104a_row20_col1, #T_3104a_row21_col1, #T_3104a_row22_col1, #T_3104a_row23_col1, #T_3104a_row24_col1, #T_3104a_row25_col1, #T_3104a_row26_col1, #T_3104a_row27_col1, #T_3104a_row28_col1, #T_3104a_row29_col1, #T_3104a_row30_col1, #T_3104a_row31_col1, #T_3104a_row32_col1, #T_3104a_row33_col1, #T_3104a_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_3104a">
#   <thead>
#     <tr>
#       <th id="T_3104a_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_3104a_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_3104a_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_3104a_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_3104a_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_3104a_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3104a_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_3104a_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_3104a_row0_col2" class="data row0 col2" >10.5</td>
#       <td id="T_3104a_row0_col3" class="data row0 col3" >10.6</td>
#       <td id="T_3104a_row0_col4" class="data row0 col4" >10.4</td>
#       <td id="T_3104a_row0_col5" class="data row0 col5" >10.5</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_3104a_row1_col1" class="data row1 col1" >21.3</td>
#       <td id="T_3104a_row1_col2" class="data row1 col2" >0.7</td>
#       <td id="T_3104a_row1_col3" class="data row1 col3" >1.4</td>
#       <td id="T_3104a_row1_col4" class="data row1 col4" >1.7</td>
#       <td id="T_3104a_row1_col5" class="data row1 col5" >1.9</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_3104a_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_3104a_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_3104a_row2_col3" class="data row2 col3" >2.7%</td>
#       <td id="T_3104a_row2_col4" class="data row2 col4" >3.3%</td>
#       <td id="T_3104a_row2_col5" class="data row2 col5" >3.8%</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_3104a_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_3104a_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_3104a_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_3104a_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_3104a_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_3104a_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_3104a_row4_col2" class="data row4 col2" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_3104a_row4_col3" class="data row4 col3" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_3104a_row4_col4" class="data row4 col4" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_3104a_row4_col5" class="data row4 col5" >12.0 (SD) → 4 (MD)</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_3104a_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_3104a_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_3104a_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_3104a_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_3104a_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_3104a_row6_col1" class="data row6 col1" ></td>
#       <td id="T_3104a_row6_col2" class="data row6 col2" ></td>
#       <td id="T_3104a_row6_col3" class="data row6 col3" ></td>
#       <td id="T_3104a_row6_col4" class="data row6 col4" ></td>
#       <td id="T_3104a_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_3104a_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_3104a_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_3104a_row7_col3" class="data row7 col3" >PS</td>
#       <td id="T_3104a_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_3104a_row7_col5" class="data row7 col5" >Hook</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_3104a_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_3104a_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_3104a_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_3104a_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_3104a_row8_col5" class="data row8 col5" >higher</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_3104a_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_3104a_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_3104a_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_3104a_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_3104a_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_3104a_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_3104a_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_3104a_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_3104a_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_3104a_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_3104a_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_3104a_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_3104a_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_3104a_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_3104a_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_3104a_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_3104a_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_3104a_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_3104a_row12_col4" class="data row12 col4" >1</td>
#       <td id="T_3104a_row12_col5" class="data row12 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_3104a_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_3104a_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_3104a_row13_col3" class="data row13 col3" >6</td>
#       <td id="T_3104a_row13_col4" class="data row13 col4" >6</td>
#       <td id="T_3104a_row13_col5" class="data row13 col5" >6</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_3104a_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_3104a_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_3104a_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_3104a_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_3104a_row14_col5" class="data row14 col5" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3104a_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_3104a_row15_col1" class="data row15 col1" >0</td>
# ### Minimize L4S1 Penalty
# *Primarily L4-S1 in ideal range (35-45°), with mech failure guard*
# <style type="text/css">
# #T_4b6b6_row0_col1, #T_4b6b6_row1_col1, #T_4b6b6_row2_col1, #T_4b6b6_row3_col1, #T_4b6b6_row4_col1, #T_4b6b6_row5_col1, #T_4b6b6_row6_col1, #T_4b6b6_row7_col1, #T_4b6b6_row8_col1, #T_4b6b6_row9_col1, #T_4b6b6_row10_col1, #T_4b6b6_row11_col1, #T_4b6b6_row12_col1, #T_4b6b6_row13_col1, #T_4b6b6_row14_col1, #T_4b6b6_row15_col1, #T_4b6b6_row16_col1, #T_4b6b6_row17_col1, #T_4b6b6_row18_col1, #T_4b6b6_row19_col1, #T_4b6b6_row20_col1, #T_4b6b6_row21_col1, #T_4b6b6_row22_col1, #T_4b6b6_row23_col1, #T_4b6b6_row24_col1, #T_4b6b6_row25_col1, #T_4b6b6_row26_col1, #T_4b6b6_row27_col1, #T_4b6b6_row28_col1, #T_4b6b6_row29_col1, #T_4b6b6_row30_col1, #T_4b6b6_row31_col1, #T_4b6b6_row32_col1, #T_4b6b6_row33_col1, #T_4b6b6_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_4b6b6">
#   <thead>
#     <tr>
#       <th id="T_4b6b6_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_4b6b6_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_4b6b6_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_4b6b6_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_4b6b6_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_4b6b6_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4b6b6_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_4b6b6_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_4b6b6_row0_col2" class="data row0 col2" >10.4</td>
#       <td id="T_4b6b6_row0_col3" class="data row0 col3" >10.5</td>
#       <td id="T_4b6b6_row0_col4" class="data row0 col4" >10.3</td>
#       <td id="T_4b6b6_row0_col5" class="data row0 col5" >10.5</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_4b6b6_row1_col1" class="data row1 col1" >8.5</td>
#       <td id="T_4b6b6_row1_col2" class="data row1 col2" >0.3</td>
#       <td id="T_4b6b6_row1_col3" class="data row1 col3" >0.9</td>
#       <td id="T_4b6b6_row1_col4" class="data row1 col4" >1.1</td>
#       <td id="T_4b6b6_row1_col5" class="data row1 col5" >1.2</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_4b6b6_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_4b6b6_row2_col2" class="data row2 col2" >1.6%</td>
#       <td id="T_4b6b6_row2_col3" class="data row2 col3" >4.0%</td>
#       <td id="T_4b6b6_row2_col4" class="data row2 col4" >5.7%</td>
#       <td id="T_4b6b6_row2_col5" class="data row2 col5" >6.0%</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_4b6b6_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_4b6b6_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_4b6b6_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_4b6b6_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_4b6b6_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_4b6b6_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_4b6b6_row4_col2" class="data row4 col2" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_4b6b6_row4_col3" class="data row4 col3" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_4b6b6_row4_col4" class="data row4 col4" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_4b6b6_row4_col5" class="data row4 col5" >12.0 (SD) → 4 (MD)</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_4b6b6_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_4b6b6_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_4b6b6_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_4b6b6_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_4b6b6_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_4b6b6_row6_col1" class="data row6 col1" ></td>
#       <td id="T_4b6b6_row6_col2" class="data row6 col2" ></td>
#       <td id="T_4b6b6_row6_col3" class="data row6 col3" ></td>
#       <td id="T_4b6b6_row6_col4" class="data row6 col4" ></td>
#       <td id="T_4b6b6_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_4b6b6_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_4b6b6_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_4b6b6_row7_col3" class="data row7 col3" >PS</td>
#       <td id="T_4b6b6_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_4b6b6_row7_col5" class="data row7 col5" >FS</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_4b6b6_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_4b6b6_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_4b6b6_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_4b6b6_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_4b6b6_row8_col5" class="data row8 col5" >lower</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_4b6b6_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_4b6b6_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_4b6b6_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_4b6b6_row9_col4" class="data row9 col4" >3</td>
#       <td id="T_4b6b6_row9_col5" class="data row9 col5" >5</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_4b6b6_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_4b6b6_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_4b6b6_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_4b6b6_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_4b6b6_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_4b6b6_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_4b6b6_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_4b6b6_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_4b6b6_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_4b6b6_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_4b6b6_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_4b6b6_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_4b6b6_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_4b6b6_row12_col4" class="data row12 col4" >1</td>
#       <td id="T_4b6b6_row12_col5" class="data row12 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_4b6b6_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_4b6b6_row13_col2" class="data row13 col2" >5</td>
#       <td id="T_4b6b6_row13_col3" class="data row13 col3" >5</td>
#       <td id="T_4b6b6_row13_col4" class="data row13 col4" >4</td>
#       <td id="T_4b6b6_row13_col5" class="data row13 col5" >5</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_4b6b6_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_4b6b6_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_4b6b6_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_4b6b6_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_4b6b6_row14_col5" class="data row14 col5" >3</td>
#     </tr>
#     <tr>
#       <td id="T_4b6b6_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_4b6b6_row15_col1" class="data row15 col1" >0</td>
#       <td
# ### Minimize T4L1PA Penalty
# *Primarily T4PA-L1PA mismatch, with mech failure guard*
# <style type="text/css">
# #T_171e8_row0_col1, #T_171e8_row1_col1, #T_171e8_row2_col1, #T_171e8_row3_col1, #T_171e8_row4_col1, #T_171e8_row5_col1, #T_171e8_row6_col1, #T_171e8_row7_col1, #T_171e8_row8_col1, #T_171e8_row9_col1, #T_171e8_row10_col1, #T_171e8_row11_col1, #T_171e8_row12_col1, #T_171e8_row13_col1, #T_171e8_row14_col1, #T_171e8_row15_col1, #T_171e8_row16_col1, #T_171e8_row17_col1, #T_171e8_row18_col1, #T_171e8_row19_col1, #T_171e8_row20_col1, #T_171e8_row21_col1, #T_171e8_row22_col1, #T_171e8_row23_col1, #T_171e8_row24_col1, #T_171e8_row25_col1, #T_171e8_row26_col1, #T_171e8_row27_col1, #T_171e8_row28_col1, #T_171e8_row29_col1, #T_171e8_row30_col1, #T_171e8_row31_col1, #T_171e8_row32_col1, #T_171e8_row33_col1, #T_171e8_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_171e8">
#   <thead>
#     <tr>
#       <th id="T_171e8_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_171e8_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_171e8_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_171e8_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_171e8_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_171e8_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_171e8_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_171e8_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_171e8_row0_col2" class="data row0 col2" >10.5</td>
#       <td id="T_171e8_row0_col3" class="data row0 col3" >10.6</td>
#       <td id="T_171e8_row0_col4" class="data row0 col4" >10.4</td>
#       <td id="T_171e8_row0_col5" class="data row0 col5" >10.5</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_171e8_row1_col1" class="data row1 col1" >8.5</td>
#       <td id="T_171e8_row1_col2" class="data row1 col2" >0.3</td>
#       <td id="T_171e8_row1_col3" class="data row1 col3" >0.6</td>
#       <td id="T_171e8_row1_col4" class="data row1 col4" >0.7</td>
#       <td id="T_171e8_row1_col5" class="data row1 col5" >0.8</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_171e8_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_171e8_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_171e8_row2_col3" class="data row2 col3" >2.7%</td>
#       <td id="T_171e8_row2_col4" class="data row2 col4" >3.3%</td>
#       <td id="T_171e8_row2_col5" class="data row2 col5" >3.8%</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_171e8_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_171e8_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_171e8_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_171e8_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_171e8_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_171e8_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_171e8_row4_col2" class="data row4 col2" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_171e8_row4_col3" class="data row4 col3" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_171e8_row4_col4" class="data row4 col4" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_171e8_row4_col5" class="data row4 col5" >12.0 (SD) → 4 (MD)</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_171e8_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_171e8_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_171e8_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_171e8_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_171e8_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_171e8_row6_col1" class="data row6 col1" ></td>
#       <td id="T_171e8_row6_col2" class="data row6 col2" ></td>
#       <td id="T_171e8_row6_col3" class="data row6 col3" ></td>
#       <td id="T_171e8_row6_col4" class="data row6 col4" ></td>
#       <td id="T_171e8_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_171e8_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_171e8_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_171e8_row7_col3" class="data row7 col3" >PS</td>
#       <td id="T_171e8_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_171e8_row7_col5" class="data row7 col5" >Hook</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_171e8_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_171e8_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_171e8_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_171e8_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_171e8_row8_col5" class="data row8 col5" >higher</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_171e8_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_171e8_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_171e8_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_171e8_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_171e8_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_171e8_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_171e8_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_171e8_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_171e8_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_171e8_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_171e8_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_171e8_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_171e8_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_171e8_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_171e8_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_171e8_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_171e8_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_171e8_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_171e8_row12_col4" class="data row12 col4" >1</td>
#       <td id="T_171e8_row12_col5" class="data row12 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_171e8_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_171e8_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_171e8_row13_col3" class="data row13 col3" >6</td>
#       <td id="T_171e8_row13_col4" class="data row13 col4" >6</td>
#       <td id="T_171e8_row13_col5" class="data row13 col5" >6</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_171e8_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_171e8_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_171e8_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_171e8_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_171e8_row14_col5" class="data row14 col5" >2</td>
#     </tr>
#     <tr>
#       <td id="T_171e8_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_171e8_row15_col1" class="data row15 col1" >0</td>
# ### Minimize GAP Score
# *Primarily overall GAP alignment score and category improvement, with mech failure guard*
# <style type="text/css">
# #T_92718_row0_col1, #T_92718_row1_col1, #T_92718_row2_col1, #T_92718_row3_col1, #T_92718_row4_col1, #T_92718_row5_col1, #T_92718_row6_col1, #T_92718_row7_col1, #T_92718_row8_col1, #T_92718_row9_col1, #T_92718_row10_col1, #T_92718_row11_col1, #T_92718_row12_col1, #T_92718_row13_col1, #T_92718_row14_col1, #T_92718_row15_col1, #T_92718_row16_col1, #T_92718_row17_col1, #T_92718_row18_col1, #T_92718_row19_col1, #T_92718_row20_col1, #T_92718_row21_col1, #T_92718_row22_col1, #T_92718_row23_col1, #T_92718_row24_col1, #T_92718_row25_col1, #T_92718_row26_col1, #T_92718_row27_col1, #T_92718_row28_col1, #T_92718_row29_col1, #T_92718_row30_col1, #T_92718_row31_col1, #T_92718_row32_col1, #T_92718_row33_col1, #T_92718_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_92718">
#   <thead>
#     <tr>
#       <th id="T_92718_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_92718_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_92718_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_92718_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_92718_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_92718_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_92718_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_92718_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_92718_row0_col2" class="data row0 col2" >1.6</td>
#       <td id="T_92718_row0_col3" class="data row0 col3" >1.6</td>
#       <td id="T_92718_row0_col4" class="data row0 col4" >1.5</td>
#       <td id="T_92718_row0_col5" class="data row0 col5" >1.5</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_92718_row1_col1" class="data row1 col1" >36.8</td>
#       <td id="T_92718_row1_col2" class="data row1 col2" >4.7</td>
#       <td id="T_92718_row1_col3" class="data row1 col3" >4.9</td>
#       <td id="T_92718_row1_col4" class="data row1 col4" >5.0</td>
#       <td id="T_92718_row1_col5" class="data row1 col5" >5.3</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_92718_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_92718_row2_col2" class="data row2 col2" >4.1%</td>
#       <td id="T_92718_row2_col3" class="data row2 col3" >5.1%</td>
#       <td id="T_92718_row2_col4" class="data row2 col4" >6.0%</td>
#       <td id="T_92718_row2_col5" class="data row2 col5" >7.3%</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_92718_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_92718_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_92718_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_92718_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_92718_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_92718_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_92718_row4_col2" class="data row4 col2" >12.0 (SD) → 1 (P)</td>
#       <td id="T_92718_row4_col3" class="data row4 col3" >12.0 (SD) → 1 (P)</td>
#       <td id="T_92718_row4_col4" class="data row4 col4" >12.0 (SD) → 1 (P)</td>
#       <td id="T_92718_row4_col5" class="data row4 col5" >12.0 (SD) → 1 (P)</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_92718_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_92718_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_92718_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_92718_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_92718_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_92718_row6_col1" class="data row6 col1" ></td>
#       <td id="T_92718_row6_col2" class="data row6 col2" ></td>
#       <td id="T_92718_row6_col3" class="data row6 col3" ></td>
#       <td id="T_92718_row6_col4" class="data row6 col4" ></td>
#       <td id="T_92718_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_92718_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_92718_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_92718_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_92718_row7_col3" class="data row7 col3" >Hook</td>
#       <td id="T_92718_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_92718_row7_col5" class="data row7 col5" >Hook</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_92718_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_92718_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_92718_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_92718_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_92718_row8_col5" class="data row8 col5" >lower</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_92718_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_92718_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_92718_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_92718_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_92718_row9_col5" class="data row9 col5" >3</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_92718_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_92718_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_92718_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_92718_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_92718_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_92718_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_92718_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_92718_row11_col3" class="data row11 col3" >1</td>
#       <td id="T_92718_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_92718_row11_col5" class="data row11 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_92718_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_92718_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_92718_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_92718_row12_col4" class="data row12 col4" >0</td>
#       <td id="T_92718_row12_col5" class="data row12 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_92718_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_92718_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_92718_row13_col2" class="data row13 col2" >5</td>
#       <td id="T_92718_row13_col3" class="data row13 col3" >5</td>
#       <td id="T_92718_row13_col4" class="data row13 col4" >4</td>
#       <td id="T_92718_row13_col5" class="data row13 col5" >4</td>
# ...
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_2e525">
#   <thead>
#     <tr>
#       <th id="T_2e525_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_2e525_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_2e525_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_2e525_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_2e525_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_2e525_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2e525_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_2e525_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_2e525_row0_col2" class="data row0 col2" >10.5</td>
#       <td id="T_2e525_row0_col3" class="data row0 col3" >10.5</td>
#       <td id="T_2e525_row0_col4" class="data row0 col4" >11.2</td>
#       <td id="T_2e525_row0_col5" class="data row0 col5" >10.4</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_2e525_row1_col1" class="data row1 col1" >9.2</td>
#       <td id="T_2e525_row1_col2" class="data row1 col2" >1.1</td>
#       <td id="T_2e525_row1_col3" class="data row1 col3" >1.5</td>
#       <td id="T_2e525_row1_col4" class="data row1 col4" >1.6</td>
#       <td id="T_2e525_row1_col5" class="data row1 col5" >1.6</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_2e525_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_2e525_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_2e525_row2_col3" class="data row2 col3" >3.2%</td>
#       <td id="T_2e525_row2_col4" class="data row2 col4" >4.3%</td>
#       <td id="T_2e525_row2_col5" class="data row2 col5" >3.9%</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_2e525_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_2e525_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_2e525_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_2e525_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_2e525_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_2e525_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_2e525_row4_col2" class="data row4 col2" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_2e525_row4_col3" class="data row4 col3" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_2e525_row4_col4" class="data row4 col4" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_2e525_row4_col5" class="data row4 col5" >12.0 (SD) → 4 (MD)</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_2e525_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_2e525_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_2e525_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_2e525_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_2e525_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_2e525_row6_col1" class="data row6 col1" ></td>
#       <td id="T_2e525_row6_col2" class="data row6 col2" ></td>
#       <td id="T_2e525_row6_col3" class="data row6 col3" ></td>
#       <td id="T_2e525_row6_col4" class="data row6 col4" ></td>
#       <td id="T_2e525_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_2e525_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_2e525_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_2e525_row7_col3" class="data row7 col3" >PS</td>
#       <td id="T_2e525_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_2e525_row7_col5" class="data row7 col5" >Hook</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_2e525_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_2e525_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_2e525_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_2e525_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_2e525_row8_col5" class="data row8 col5" >lower</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_2e525_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_2e525_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_2e525_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_2e525_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_2e525_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_2e525_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_2e525_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_2e525_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_2e525_row10_col4" class="data row10 col4" >1</td>
#       <td id="T_2e525_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_2e525_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_2e525_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_2e525_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_2e525_row11_col4" class="data row11 col4" >0</td>
#       <td id="T_2e525_row11_col5" class="data row11 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_2e525_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_2e525_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_2e525_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_2e525_row12_col4" class="data row12 col4" >1</td>
#       <td id="T_2e525_row12_col5" class="data row12 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_2e525_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_2e525_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_2e525_row13_col3" class="data row13 col3" >5</td>
#       <td id="T_2e525_row13_col4" class="data row13 col4" >5</td>
#       <td id="T_2e525_row13_col5" class="data row13 col5" >5</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_2e525_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_2e525_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_2e525_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_2e525_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_2e525_row14_col5" class="data row14 col5" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2e525_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_2e525_row15_col1" class="data row15 col1" >0</td>
#       <
# ### Minimize Postop ODI
# *Primarily lowest predicted postoperative ODI, with mech failure guard*
# <style type="text/css">
# #T_406fc_row0_col1, #T_406fc_row1_col1, #T_406fc_row2_col1, #T_406fc_row3_col1, #T_406fc_row4_col1, #T_406fc_row5_col1, #T_406fc_row6_col1, #T_406fc_row7_col1, #T_406fc_row8_col1, #T_406fc_row9_col1, #T_406fc_row10_col1, #T_406fc_row11_col1, #T_406fc_row12_col1, #T_406fc_row13_col1, #T_406fc_row14_col1, #T_406fc_row15_col1, #T_406fc_row16_col1, #T_406fc_row17_col1, #T_406fc_row18_col1, #T_406fc_row19_col1, #T_406fc_row20_col1, #T_406fc_row21_col1, #T_406fc_row22_col1, #T_406fc_row23_col1, #T_406fc_row24_col1, #T_406fc_row25_col1, #T_406fc_row26_col1, #T_406fc_row27_col1, #T_406fc_row28_col1, #T_406fc_row29_col1, #T_406fc_row30_col1, #T_406fc_row31_col1, #T_406fc_row32_col1, #T_406fc_row33_col1, #T_406fc_row34_col1 {
#   background-color: rgba(255,255,255,0.08);
# }
# </style>
# <table id="T_406fc">
#   <thead>
#     <tr>
#       <th id="T_406fc_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_406fc_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_406fc_level0_col2" class="col_heading level0 col2" >Sol 1</th>
#       <th id="T_406fc_level0_col3" class="col_heading level0 col3" >Sol 2</th>
#       <th id="T_406fc_level0_col4" class="col_heading level0 col4" >Sol 3</th>
#       <th id="T_406fc_level0_col5" class="col_heading level0 col5" >Sol 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_406fc_row0_col0" class="data row0 col0" >Alignment Score</td>
#       <td id="T_406fc_row0_col1" class="data row0 col1" >11.6</td>
#       <td id="T_406fc_row0_col2" class="data row0 col2" >10.5</td>
#       <td id="T_406fc_row0_col3" class="data row0 col3" >10.6</td>
#       <td id="T_406fc_row0_col4" class="data row0 col4" >10.4</td>
#       <td id="T_406fc_row0_col5" class="data row0 col5" >10.5</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row1_col0" class="data row1 col0" >Optimization Score</td>
#       <td id="T_406fc_row1_col1" class="data row1 col1" >8.5</td>
#       <td id="T_406fc_row1_col2" class="data row1 col2" >0.3</td>
#       <td id="T_406fc_row1_col3" class="data row1 col3" >0.6</td>
#       <td id="T_406fc_row1_col4" class="data row1 col4" >0.7</td>
#       <td id="T_406fc_row1_col5" class="data row1 col5" >0.8</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row2_col0" class="data row2 col0" >Mech Fail Prob</td>
#       <td id="T_406fc_row2_col1" class="data row2 col1" >42.7%</td>
#       <td id="T_406fc_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_406fc_row2_col3" class="data row2 col3" >2.7%</td>
#       <td id="T_406fc_row2_col4" class="data row2 col4" >3.3%</td>
#       <td id="T_406fc_row2_col5" class="data row2 col5" >3.8%</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row3_col0" class="data row3 col0" >Predicted ODI</td>
#       <td id="T_406fc_row3_col1" class="data row3 col1" >N/A</td>
#       <td id="T_406fc_row3_col2" class="data row3 col2" >N/A</td>
#       <td id="T_406fc_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_406fc_row3_col4" class="data row3 col4" >N/A</td>
#       <td id="T_406fc_row3_col5" class="data row3 col5" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row4_col0" class="data row4 col0" >GAP Score</td>
#       <td id="T_406fc_row4_col1" class="data row4 col1" >12.0 (SD) → 5 (MD)</td>
#       <td id="T_406fc_row4_col2" class="data row4 col2" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_406fc_row4_col3" class="data row4 col3" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_406fc_row4_col4" class="data row4 col4" >12.0 (SD) → 4 (MD)</td>
#       <td id="T_406fc_row4_col5" class="data row4 col5" >12.0 (SD) → 4 (MD)</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row5_col0" class="data row5 col0" >────────────</td>
#       <td id="T_406fc_row5_col1" class="data row5 col1" >──────────</td>
#       <td id="T_406fc_row5_col2" class="data row5 col2" >──────────</td>
#       <td id="T_406fc_row5_col3" class="data row5 col3" >──────────</td>
#       <td id="T_406fc_row5_col4" class="data row5 col4" >──────────</td>
#       <td id="T_406fc_row5_col5" class="data row5 col5" >──────────</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row6_col0" class="data row6 col0" >SURGICAL PLAN</td>
#       <td id="T_406fc_row6_col1" class="data row6 col1" ></td>
#       <td id="T_406fc_row6_col2" class="data row6 col2" ></td>
#       <td id="T_406fc_row6_col3" class="data row6 col3" ></td>
#       <td id="T_406fc_row6_col4" class="data row6 col4" ></td>
#       <td id="T_406fc_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row7_col0" class="data row7 col0" >UIV_implant</td>
#       <td id="T_406fc_row7_col1" class="data row7 col1" >Hook</td>
#       <td id="T_406fc_row7_col2" class="data row7 col2" >Hook</td>
#       <td id="T_406fc_row7_col3" class="data row7 col3" >PS</td>
#       <td id="T_406fc_row7_col4" class="data row7 col4" >Hook</td>
#       <td id="T_406fc_row7_col5" class="data row7 col5" >Hook</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row8_col0" class="data row8 col0" >num_levels_cat</td>
#       <td id="T_406fc_row8_col1" class="data row8 col1" >higher</td>
#       <td id="T_406fc_row8_col2" class="data row8 col2" >lower</td>
#       <td id="T_406fc_row8_col3" class="data row8 col3" >lower</td>
#       <td id="T_406fc_row8_col4" class="data row8 col4" >lower</td>
#       <td id="T_406fc_row8_col5" class="data row8 col5" >higher</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row9_col0" class="data row9 col0" >num_interbody_fusion_levels</td>
#       <td id="T_406fc_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_406fc_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_406fc_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_406fc_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_406fc_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row10_col0" class="data row10 col0" >ALIF</td>
#       <td id="T_406fc_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_406fc_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_406fc_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_406fc_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_406fc_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row11_col0" class="data row11 col0" >XLIF</td>
#       <td id="T_406fc_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_406fc_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_406fc_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_406fc_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_406fc_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row12_col0" class="data row12 col0" >TLIF</td>
#       <td id="T_406fc_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_406fc_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_406fc_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_406fc_row12_col4" class="data row12 col4" >1</td>
#       <td id="T_406fc_row12_col5" class="data row12 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row13_col0" class="data row13 col0" >num_rods</td>
#       <td id="T_406fc_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_406fc_row13_col2" class="data row13 col2" >6</td>
#       <td id="T_406fc_row13_col3" class="data row13 col3" >6</td>
#       <td id="T_406fc_row13_col4" class="data row13 col4" >6</td>
#       <td id="T_406fc_row13_col5" class="data row13 col5" >6</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row14_col0" class="data row14 col0" >num_pelvic_screws</td>
#       <td id="T_406fc_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_406fc_row14_col2" class="data row14 col2" >2</td>
#       <td id="T_406fc_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_406fc_row14_col4" class="data row14 col4" >2</td>
#       <td id="T_406fc_row14_col5" class="data row14 col5" >2</td>
#     </tr>
#     <tr>
#       <td id="T_406fc_row15_col0" class="data row15 col0" >osteotomy (PSO)</td>
#       <td id="T_406fc_row15_col1" class="data row15 col1" >0</td>
