# %%
import pandas as pd
import numpy as np

# %%
#load cleaned patient data
df = pd.read_csv("../data/cleaned/MSDS_cleaned_0122.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 98 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            277 non-null    int64
#  1   age                           277 non-null    int64
#  2   sex                           277 non-null    object
#  3   bmi                           250 non-null    float64
#  4   Race                          276 non-null    object
#  5   LOS_min                       276 non-null    float64
#  6   PROC_TIME_MIN                 276 non-null    float64
#  7   SMOKING                       228 non-null    object
#  8   C7CSVL_preop                  274 non-null    float64
#  9   SVA_preop                     275 non-null    float64
#  10  TK_T4_T12_preop               275 non-null    float64
#  11  TK_T10_L2_preop               275 non-null    float64
#  12  T4PA_preop                    275 non-null    float64
#  13  L1PA_preop                    275 non-null    float64
#  14  L1PA_ideal                    277 non-null    float64
#  15  T4L1PA_preop                  277 non-null    float64
#  16  global_tilt                   274 non-null    float64
#  17  LL_preop                      275 non-null    float64
#  18  L4S1_preop                    275 non-null    float64
#  19  L5S1_preop                    275 non-null    float64
#  20  PT_preop                      275 non-null    float64
#  21  PI_preop                      275 non-null    float64
#  22  PI_LL_preop                   277 non-null    float64
#  23  SS_preop                      277 non-null    float64
#  24  cobb_prox_curve_preop         200 non-null    float64
#  25  EV_prox_prox_preop            200 non-null    object
#  26  EV_distal_prox_preop          200 non-null    object
#  27  cobb_main_curve_preop         223 non-null    float64
#  28  EV_prox_main_preop            223 non-null    object
#  29  EV_distal_main_preop          223 non-null    object
#  30  cobb_distal_curve_preop       215 non-null    float64
#  31  EV_prox_distal_preop          215 non-null    object
#  32  EV_distal_distal_preop        215 non-null    object
#  33  FC_preop                      268 non-null    float64
#  34  EV_prox_FC                    268 non-null    object
#  35  tscore_femneck_preop          199 non-null    float64
#  36  HU_UIV_preop                  230 non-null    float64
#  37  HU_UIVplus1_preop             227 non-null    float64
#  38  HU_UIVplus2_preop             223 non-null    float64
#  39  C7CSVL_postop
#                 270 non-null    float64
#  40  SVA_postop
#                    272 non-null    float64
#  41  TK_T4_T12_postop              272 non-null    float64
#  42  TK_T10_L2_postop              272 non-null    float64
#  43  PJA_postop                    268 non-null    float64
#  44  T4PA_postop                   272 non-null    float64
#  45  L1PA_postop                   272 non-null    float64
#  46  L1PA_ideal_mismatch_postop    275 non-null    float64
#  47  T4L1PA_ideal_mismatch_postop  275 non-null    float64
#  48  global_tilt.1                 272 non-null    float64
#  49  LL_postop                     272 non-null    float64
#  50  L4_S1_postop                  272 non-null    float64
#  51  L5_S1_postop                  272 non-null    float64
#  52  PT_postop                     272 non-null    float64
#  53  PI_postop                     272 non-null    float64
#  54  PI_LL_postop                  198 non-null    float64
#  55  SS_postop                     197 non-null    float64
#  56  cobb_prox_curve_postop        182 non-null    float64
#  57  EV_prox_prox_postop           181 non-null    object
#  58  EV_distal_prox_postop         181 non-null    object
#  59  cobb_main_curve_postop        211 non-null    float64
#  60  EV_prox_main_postop           211 non-null    object
#  61  EV_distal_main_postop         211 non-null    object
#  62  cobb_distal_curve_postop      195 non-null    float64
#  63  EV_prox_distal_postop         195 non-null    object
#  64  EV_distal_distal_postop       195 non-null    object
#  65  FC_postop                     262 non-null    float64
#  66  num_levels                    276 non-null    object
#  67  num_interbody_fusion_levels   275 non-null    float64
#  68  UIV_implant                   276 non-null    object
#  69  ALIF                          277 non-null    int64
#  70  XLIF                          277 non-null    int64
#  71  TLIF                          277 non-null    int64
#  72  num_rods                      275 non-null    float64
#  73  num_pelvic_screws             275 non-null    float64
#  74  osteotomy                     275 non-null    float64
#  75  mech_fail_last                251 non-null    float64
#  76  RPV_preop                     268 non-null    float64
#  77  RPV_score_preop               277 non-null    int64
#  78  RLL_preop                     277 non-null    float64
#  79  RLL_score_preop               277 non-null    int64
#  80  LDI_preop                     277 non-null    object
#  81  LDI_score_preop               277 non-null    object
#  82  RSA_preop                     277 non-null    float64
#  83  RSA_score_preop               277 non-null    int64
#  84  gap_age_poin_preop            277 non-null    int64
#  85  gap_score_preop               277 non-null    object
#  86  gap_category                  277 non-null    object
#  87  RPV_postop                    277 non-null    float64
#  88  RPV_score_postop              277 non-null    int64
#  89  RLL_postop                    277 non-null    float64
#  90  RLL_score_postop              277 non-null    int64
#  91  LDI_postop                    277 non-null    object
#  92  LDI_score_postop              277 non-null    object
#  93  RSA_postop                    277 non-null    float64
#  94  RSA_score_postop              277 non-null    int64
#  95  gap_age_point_postop          277 non-null    int64
#  96  gap_score_postop              277 non-null    object
#  97  gap_category_postop           277 non-null    object
# dtypes: float64(59), int64(13), object(26)
# memory usage: 212.2+ KB

# %% [markdown]
# #### 1. Calculation of Composite Score
#
# The parameters used in computing the composite score are the GAP score, L1PA penalty, L4SI penalty, T4L1PA penalty, LL penalty, and improvement in GAP category (P, MD, SD). The parameters are given equal weights.
#
# Calculation method:
#
# GAP: The GAP score (1-13) is converted to a 0-100 scale.
#
# Penalties: Quadratic penalties are calculated for violation of the respective constraints and normalized based on the maximum violation in the dataset. Then the (weighted) penalties are added to the composite score.
#
# Improvement in GAP (Option 2 in calculation doc):
#
# No penalty is applied if the patient's condition improved from severely disproportioned or moderately disproportioned to proportioned. Otherwise, a penalty of 30 is applied if the patient's condition improved from severely disproportioned to moderately disproportioned. A penalty of 100 is added if the patient's condition remains in the same category or worsens.
#
# * note : may need to find a better way to normalize

# %%
#create a score system for gap change based on change in gap category - option 1
# df["gap_category_postop"] = pd.cut(df["gap_score_postop"], bins=[-np.inf, 2, 6, 13], labels=["P", "MD", "SD"])
df["gap_score_postop"] = pd.to_numeric(df["gap_score_postop"], errors="coerce")

def composite_score_calc(df, w1=1, w2=1, w3=1, w4=1, w5=1, w6=1):
    """
    Compute composite score based on gap score and quadartic penalties for constraint violations.

    Parameters:
    df: patient surgical data in Pandas DataFrame
    w1: weight for L1PA penalty
    w2: weight for L4S1 penalty
    w3: weight for T4L1PA penalty
    w4: weight for LL penalty
    w5: weight for gap improvement score
    multiplier : scaling factor for penalties (since gap score is on a different scale)

   Returns:
   composite scores 
    """
    #calculate relative weights
    weights = [w1, w2, w3, w4, w5, w6]
    total_weight = sum(weights)
    rel_weights = [w / total_weight for w in weights]

    # convert gap scores to numpy array for simpler calculations
    gap_score_postop = np.array(df["gap_score_postop"] * 100/13)
   
    # calculate constraint penalties

    # 1) L1PA quadratic penalty
    l1pa_pen = [0 if abs(i) <= 3 else (abs(i)-3)**2 for i in df["L1PA_ideal_mismatch_postop"]]

    #normalize L1PA penalty
    l1pa_pen = np.array(l1pa_pen) / max(l1pa_pen) * 100

    # 2) L4S1 quadratic penalty
    l4s1_pen = [0 if 35 <= i <= 45 else (35 - i) ** 2 if i < 35 else (i - 45) ** 2 for i in df["L4_S1_postop"]]
   
    #normalize L4S1 penalty
    l4s1_pen = np.array(l4s1_pen) / max(l4s1_pen) * 100

    # 3) T4L1PA penalty
    t4l1pa_pen = [0 if abs(i) <= 3 else (abs(i)-3)**2 for i in df["T4L1PA_ideal_mismatch_postop"]]
    
    #normalize T4L1PA penalty
    t4l1pa_pen = np.array(t4l1pa_pen)/ max(t4l1pa_pen) * 100
 
    # 4) LL penalty
    ll_ideal = 0.54 * df["PI_preop"] + 27.6
    ll_mismatch = df["LL_postop"] - ll_ideal
    ll_pen = [0 if abs(i) <= 3 else (abs(i) - 3) ** 2 for i in ll_mismatch]
  
    #normalize LL penalty 
    ll_pen = (np.array(ll_pen)) / max(ll_pen) * 100

    #gap improvement score based on category change

    gap_category_improvement = []
    for i in range(len(df)):
        if df["gap_category_postop"][i] =="P" and (df["gap_category"][i]) in ["SD","MD", "P"]:
            gap_category_improvement.append(0)
        elif df["gap_category_postop"][i] =="MD" and df["gap_category"][i] == "SD":
            gap_category_improvement.append(30)
        else:
            gap_category_improvement.append(100)
    gap_category_improvement = np.array(gap_category_improvement)

    # Composite score

    composite = (rel_weights[0] * gap_score_postop +
                rel_weights[1] * l1pa_pen +
                rel_weights[2] * l4s1_pen +
                rel_weights[3] * t4l1pa_pen +
                rel_weights[4] * ll_pen +
                rel_weights[5] * gap_category_improvement)
    
    return composite


composite_scores = composite_score_calc(df) #weights can be adjusted here

print(composite_scores)
# Out:
# [4.53911818e+00 4.73532146e+00 3.37820757e+01 1.43607469e+01
#  1.10141362e+01 5.66084573e+00 1.28205128e+00 2.88521608e+01
#  3.00748136e+01 4.02580157e+00 1.48550934e+00 3.36793997e+01
#  3.35964618e+00 1.29463426e+01 3.11357738e+01 2.31154303e+01
#  1.37546008e+01 2.42429781e+01 2.35439738e+00 2.72105719e+01
#  1.29407836e+01 1.75295319e+00 5.42402497e+01 2.96615515e+01
#  1.53206754e+00            nan 1.81848439e+00 2.56457224e+01
#  2.45609025e+01 1.41785348e+00 8.85545386e+00 4.83809088e+00
#  3.01349654e+01 2.09467020e+01 1.12888276e+01 1.54585156e+00
#  2.61419445e+01 2.31277670e+01 2.56595442e+01 2.78038499e+01
#  2.08265348e+01 3.59840168e+01 7.09159154e+00 3.24835787e+01
#  1.74093372e+01 1.40998472e+00 1.49353811e+00 3.25710276e+01
#  1.02145170e+01 2.15696797e+01 1.85893969e+00 8.72125669e+00
#  5.21667640e+01 1.73787341e+00 1.48940688e+00 3.24633378e+01
#  2.16596391e+00 2.64486145e+01 2.28812268e-01 3.08441103e+01
#  2.17974003e+00 2.33735710e+01 1.29994929e+01 1.54837776e+01
#  3.44751574e+01 2.88543925e+01 1.20420625e+01 2.92497157e+01
#  2.53269215e+01 1.28503995e+00 2.17843892e+00 1.29504823e+00
#  3.05907566e+01 1.78776836e+01 1.12590119e+01 1.26503618e+01
#  2.23233893e+01 2.59787967e+01 4.74020127e+01 2.87091835e+01
#  2.99812238e+01 1.40277608e+01 2.94416413e+01 3.39072201e+01
#  2.45030737e+01 2.62133924e+00 4.69386500e+01 3.72328358e+01
#  2.48882984e+00 3.33717198e+01 1.22575945e+01 3.44586663e+00
#  1.39043888e+01 1.31516008e+01 3.57495649e+01 3.54005200e+01
#  4.11235419e+01 2.12383098e+01 9.61740407e+00 2.71137448e+01
#  1.29819596e+01 2.36798418e+00 3.67306642e+01 3.42704461e+01
#  1.50974263e+01 1.59293709e+01 1.44825078e+01 4.64674766e+01
#  1.16934823e+01            nan 2.96900802e+01 3.32724503e+01
#  2.92754104e+01 3.42685933e+01 1.05926533e+01 2.51957204e+01
#  2.26404214e+01 9.34993627e+00 1.22272824e+01 3.61812940e+01
#  2.31369804e+01 2.38174279e+01 2.93284306e+01 1.17283247e+01
#  1.80179844e+01 1.75400049e+00 1.41897167e+01 1.87002508e+01
#  1.03344540e+01 1.32686844e+01 2.67116380e+01 1.28630228e+01
#  1.19113155e+01 5.20116741e+01 1.51546813e+01 1.14063290e+01
#  4.72792363e+01 1.35829098e+01 5.70039201e+01 1.59769670e+01
#  7.54367695e+00 1.63947936e+01 3.02899995e+00 4.93237787e+01
#  2.32968964e+01 3.05795223e+01 1.53355925e-02 3.11868757e+01
#             nan 2.18493212e+01 3.31407685e+01 4.33062210e+01
#  1.41003464e+01            nan 3.08689308e+01 2.61701005e+01
#  4.09973805e+01 2.69717438e+01 2.50015642e+01 3.35485789e+01
#  9.60997197e+00 3.56052082e+00 1.33531425e+01 3.73768673e+00
#  3.26942579e+01 2.73943097e+00 2.64682795e+01 1.63277186e+01
#  1.36514743e+01 3.01980348e+00 1.85562535e+01 1.15659002e+01
#  3.18549243e+01 3.14307973e+01 2.78002590e+01 2.47230121e+01
#  2.86378146e+01 1.28712159e+00 2.58019936e+01 3.58447794e+01
#  4.16614245e+00 2.19542875e+01 2.09678125e+01 1.58593505e+01
#  8.96646992e+00 1.31925136e+00 2.98737408e+01 2.97923397e+00
#  1.38710560e+00 2.80602032e+00 2.84459130e+01 4.32282373e+01
#  3.21455381e+00 1.01283460e+01 3.14153694e+01 2.47750222e+01
#  1.10675221e+01 3.43147251e+01 3.05199945e+01 1.02523809e+01
#  1.15506602e+01 3.50969592e+01 1.28057799e+01 1.36091675e+01
#  1.85763221e+01 2.83951950e+00 3.19219992e+00 1.50292389e+01
#  3.81451587e+01 2.14770730e+00 3.47084665e+01 9.19684206e+00
#  2.63571205e+01 1.42136090e+00 1.38324043e+01 1.09901260e+01
#  2.81295032e+01 2.80700140e+01 1.06744215e+01 4.06306399e+01
#  2.79226538e+01 1.04690925e+01 1.52438640e+01 2.67866494e+01
#  3.02225331e+01 1.12030074e+01 1.29066994e+00 1.62768917e+01
#  3.53644838e+01 2.75306948e+01 1.29012190e+00 1.77635574e+01
#  1.12298354e+01 1.33123182e+00 1.49307369e+01 5.05518560e+00
#  1.32806183e+01 1.15338592e+01 1.03886218e+01 1.34397968e+01
#  2.73808354e+01 2.21846707e+01 2.23077263e+01 1.01282051e+01
#  8.86388851e+00 2.23626773e+01 1.32295432e+00 3.63803721e+00
#  2.94598375e+01 1.01698718e+01 2.44819616e+01 1.06283395e+01
#  9.10657051e+00 2.16159651e+01 1.53793739e+00 4.16694918e+00
#  2.63865443e+01 2.29218950e+00 2.66596728e+01 2.22371550e+01
#  3.46157489e+01 0.00000000e+00 1.25239764e+01 4.24586027e+01
#  1.39647747e+01 2.58964010e+01 2.71359867e+00 1.77893848e+00
#  2.97490476e+01 3.00606725e+01 2.15429792e+00 1.31098647e+00
#  1.08377243e+01 3.39792926e+01 4.18731970e+01            nan
#  3.24604267e+01]

# %% [markdown]
# ##### 2. Add Composite Scores to Data Frame

# %%
#show all rows
pd.set_option("display.max_rows", None)

df["composite_scores"] = pd.DataFrame(composite_scores)
print(df[["gap_score_postop","composite_scores"]])
# Out:
#      gap_score_postop  composite_scores
# 0                 2.0          4.539118
# 1                 1.0          4.735321
# 2                 9.0         33.782076
# 3                 4.0         14.360747
# 4                 4.0         11.014136
# 5                 2.0          5.660846
# 6                 1.0          1.282051
# 7                 9.0         28.852161
# 8                 7.0         30.074814
# 9                 1.0          4.025802
# 10                1.0          1.485509
# 11                9.0         33.679400
# 12                2.0          3.359646
# 13                4.0         12.946343
# 14               10.0         31.135774
# 15                5.0         23.115430
# 16                6.0         13.754601
# 17                4.0         24.242978
# 18                1.0          2.354397
# 19                7.0         27.210572
# 20                6.0         12.940784
# 21                1.0          1.752953
# 22               13.0         54.240250
# 23                7.0         29.661552
# 24                1.0          1.532068
# 25                NaN               NaN
# 26                1.0          1.818484
# 27                7.0         25.645722
# 28                3.0         24.560902
# 29                1.0          1.417853
# 30                3.0          8.855454
# 31                1.0          4.838091
# 32                9.0         30.134965
# 33                6.0         20.946702
# 34                4.0         11.288828
# 35                1.0          1.545852
# 36                4.0         26.141944
# 37                5.0         23.127767
# 38                7.0         25.659544
# 39                7.0         27.803850
# 40                3.0         20.826535
# 41               10.0         35.984017
# 42                2.0          7.091592
# 43                9.0         32.483579
# 44                6.0         17.409337
# 45                1.0          1.409985
# 46                1.0          1.493538
# 47               10.0         32.571028
# 48                4.0         10.214517
# 49                3.0         21.569680
# 50                1.0          1.858940
# 51                1.0          8.721257
# 52               10.0         52.166764
# 53                1.0          1.737873
# 54                1.0          1.489407
# 55                8.0         32.463338
# 56                1.0          2.165964
# 57                6.0         26.448614
# 58                0.0          0.228812
# 59                7.0         30.844110
# 60                0.0          2.179740
# 61                4.0         23.373571
# 62                4.0         12.999493
# 63                6.0         15.483778
# 64                8.0         34.475157
# 65                8.0         28.854393
# 66                4.0         12.042063
# 67                8.0         29.249716
# 68                5.0         25.326922
# 69                1.0          1.285040
# 70                1.0          2.178439
# 71                1.0          1.295048
# 72                3.0         30.590757
# 73                6.0         17.877684
# 74                4.0         11.259012
# 75                4.0         12.650362
# 76                4.0         22.323389
# 77                5.0         25.978797
# 78                8.0         47.402013
# 79                7.0         28.709184
# 80                5.0         29.981224
# 81                5.0         14.027761
# 82                7.0         29.441641
# 83                9.0         33.907220
# 84                5.0         24.503074
# 85                2.0          2.621339
# 86               13.0         46.938650
# 87                9.0         37.232836
# 88                0.0          2.488830
# 89                8.0         33.371720
# 90                5.0         12.257595
# 91                1.0          3.445867
# 92                6.0         13.904389
# 93                5.0         13.151601
# 94                6.0         35.749565
# 95                7.0         35.400520
# 96                8.0         41.123542
# 97                3.0         21.238310
# 98                3.0          9.617404
# 99                7.0         27.113745
# 100               5.0         12.981960
# 101               1.0          2.367984
# 102               8.0         36.730664
# 103              10.0         34.270446
# 104               6.0         15.097426
# 105               6.0         15.929371
# 106               6.0         14.482508
# 107              11.0         46.467477
# 108               5.0         11.693482
# 109               NaN               NaN
# 110               8.0         29.690080
# 111               7.0         33.272450
# 112               8.0         29.275410
# 113              10.0         34.268593
# 114               4.0         10.592653
# 115               5.0         25.195720
# 116               4.0         22.640421
# 117               3.0          9.349936
# 118               4.0         12.227282
# 119              10.0         36.181294
# 120               6.0         23.136980
# 121               5.0         23.817428
# 122               8.0         29.328431
# 123               5.0         11.728325
# 124               4.0         18.017984
# 125               1.0          1.754000
# 126               6.0         14.189717
# 127               6.0         18.700251
# 128               4.0         10.334454
# 129               4.0         13.268684
# 130               7.0         26.711638
# 131               4.0         12.863023
# 132               3.0         11.911315
# 133              13.0         52.011674
# 134               6.0         15.154681
# 135               4.0         11.406329
# 136              11.0         47.279236
# 137               6.0         13.582910
# 138              13.0         57.003920
# 139               6.0         15.976967
# 140               1.0          7.543677
# 141               5.0         16.394794
# 142               0.0          3.029000
# 143               9.0         49.323779
# 144               5.0         23.296896
# 145               7.0         30.579522
# 146               0.0          0.015336
# 147               9.0         31.186876
# 148               NaN               NaN
# 149               6.0         21.849321
# 150               9.0         33.140769
# 151              12.0         43.306221
# 152               4.0         14.100346
# 153               NaN               NaN
# 154               7.0         30.868931
# 155               7.0         26.170101
# 156               8.0         40.997381
# 157               7.0         26.971744
# 158               5.0         25.001564
# 159               8.0         33.548579
# 160               3.0          9.609972
# 161               1.0          3.560521
# 162               1.0         13.353143
# 163               2.0          3.737687
# 164               7.0         32.694258
# 165               2.0          2.739431
# 166               5.0         26.468279
# 167               6.0         16.327719
# 168               6.0         13.651474
# 169               2.0          3.019803
# 170               6.0         18.556253
# 171               3.0         11.565900
# 172               8.0         31.854924
# 173               7.0         31.430797
# 174               7.0         27.800259
# 175               6.0         24.723012
# 176               7.0         28.637815
# 177               1.0          1.287122
# 178               7.0         25.801994
# 179              11.0         35.844779
# 180               1.0          4.166142
# 181               4.0         21.954288
# 182               3.0         20.967812
# 183               6.0         15.859351
# 184               3.0          8.966470
# 185               1.0          1.319251
# 186               7.0         29.873741
# 187               1.0          2.979234
# 188               1.0          1.387106
# 189               2.0          2.806020
# 190               8.0         28.445913
# 191              12.0         43.228237
# 192               1.0          3.214554
# 193               4.0         10.128346
# 194               8.0         31.415369
# 195               5.0         24.775022
# 196               3.0         11.067522
# 197              10.0         34.314725
# 198               9.0         30.519994
# 199               4.0         10.252381
# 200               5.0         11.550660
# 201              10.0         35.096959
# 202               4.0         12.805780
# 203               6.0         13.609168
# 204               6.0         18.576322
# 205               2.0          2.839519
# 206               2.0          3.192200
# 207               6.0         15.029239
# 208               9.0         38.145159
# 209               1.0          2.147707
# 210              11.0         34.708467
# 211               3.0          9.196842
# 212               6.0         26.357121
# 213               1.0          1.421361
# 214               5.0         13.832404
# 215               4.0         10.990126
# 216               6.0         28.129503
# 217               8.0         28.070014
# 218               4.0         10.674422
# 219              11.0         40.630640
# 220               7.0         27.922654
# 221               4.0         10.469093
# 222               6.0         15.243864
# 223               6.0         26.786649
# 224               7.0         30.222533
# 225               4.0         11.203007
# 226               1.0          1.290670
# 227               4.0         16.276892
# 228              11.0         35.364484
# 229               8.0         27.530695
# 230               1.0          1.290122
# 231               4.0         17.763557
# 232               4.0         11.229835
# 233               1.0          1.331232
# 234               6.0         14.930737
# 235               2.0          5.055186
# 236               6.0         13.280618
# 237               3.0         11.533859
# 238               4.0         10.388622
# 239               6.0         13.439797
# 240               8.0         27.380835
# 241               4.0         22.184671
# 242               4.0         22.307726
# 243               4.0         10.128205
# 244               3.0          8.863889
# 245               4.0         22.362677
# 246               1.0          1.322954
# 247               1.0          3.638037
# 248               7.0         29.459837
# 249               4.0         10.169872
# 250               6.0         24.481962
# 251               4.0         10.628339
# 252               3.0          9.106571
# 253               3.0         21.615965
# 254               1.0          1.537937
# 255               2.0          4.166949
# 256               7.0         26.386544
# 257               1.0          2.292190
# 258               7.0         26.659673
# 259               4.0         22.237155
# 260               9.0         34.615749
# 261               0.0          0.000000
# 262               4.0         12.523976
# 263               7.0         42.458603
# 264               6.0         13.964775
# 265               7.0         25.896401
# 266               1.0          2.713599
# 267               1.0          1.778938
# 268               9.0         29.749048
# 269               7.0         30.060673
# 270               1.0          2.154298
# 271               1.0          1.310986
# 272               4.0         10.837724
# 273               8.0         33.979293
# 274               7.0         41.873197
# 275               NaN               NaN
# 276               7.0         32.460427

# %%
# Save dataframe with composite scores to intermediate folder
output_path = "../data/intermediate/MSDS_database_with_composite_scores.csv"
df.to_csv(output_path, index=False)
print(f"Saved dataframe with composite scores to {output_path}")
# Out:
# Saved dataframe with composite scores to ../data/intermediate/MSDS_database_with_composite_scores.csv
